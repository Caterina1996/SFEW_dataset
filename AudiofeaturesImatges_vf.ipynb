# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %%capture
# !pip install ffmpeg

# %%
# %%capture
# !unzip "/content/gdrive/My Drive/EmotiW_2018.zip"

# %%
import ffmpeg
import glob, os,shutil

import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
from numpy import save

import pandas as pd
from google.colab import files
import zipfile
from pathlib import Path

import librosa                    
import librosa.display
import IPython.display as ipd
import scipy.io.wavfile
from scipy.fftpack import dct
from scipy import signal


import operator
import keras
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Conv2D, BatchNormalization, MaxPooling2D,Activation
from keras import applications
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras import applications
from keras.callbacks import ModelCheckpoint,CSVLogger
from keras import regularizers, optimizers

import sklearn.metrics as sk_metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import itertools

import tensorflow as tf

#sense els imports així passen coses rares:
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
from keras.models import Model

import sys
# sys.path.insert(0,'/content/gdrive/MyDrive/Colab Notebooks/test.py')

# %%
# set random seed 
from numpy.random import seed
seed(42)
from tensorflow import random
random.set_seed(42)

# %%
from numpy.random import seed
seed(1)

from tensorflow import random
random.set_seed(2)

# %%
dict_xy_afew={}
train_set_path='EmotiW_2018/Train_AFEW/'
test_set_path='EmotiW_2018/Val_AFEW/'

# %%
os.remove(train_set_path+'Train_6.xml')
os.remove(train_set_path+'AlignedFaces_LBPTOP_Points.zip')
os.remove(test_set_path+'Val_6.xml')
os.remove(test_set_path+'AlignedFaces_LBPTOP_Points_Val.zip')
emotions=sorted(os.listdir(train_set_path))
print(emotions)
# Out:
# ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# %%
num_emotions=7
emo_dict={}
for emo,i in zip(emotions, range(num_emotions+1)):
  emo_dict[emo]=i
print(emo_dict)
emo_dict_reversed = {v: k for k, v in emo_dict.items()}
print(emo_dict_reversed)
# Out:
# {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}
# {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# %%
# !rm -rf Test_audio_ne/
# !rm -rf Train_audio_ne

# %%
def convert_to_audio_ne(set_path,set_name):
  f = open("convert_to_audio.sh", "w")
  path_afew_set=set_path
  urls_afew = glob.glob(pathname=path_afew_set + '*')
  print(urls_afew)
  print("-------------------")
  for url_emo in urls_afew:
    urls_emotion = glob.glob(pathname=url_emo + '/*')
    # print(urls_emotion)
    emo=os.path.basename(url_emo)
    new_dir=set_name+'_audio_ne/'
    if not os.path.exists(set_name+'_audio_ne'):
      os.makedirs(set_name+'_audio_ne')
    print(emo)
    for video_file in urls_emotion:
      pass
      file_name=os.path.splitext(os.path.basename(video_file))
      f.write("ffmpeg -i "+video_file+" -vn -ac 1 "+new_dir+file_name[0]+".wav"+'\n')
      dict_xy_afew[file_name[0]]=emo
  f.close()

# %%
# %%capture
#Extraemos el audio de los vídeos del AFEW
# !rm -rf Train_audio_ne
convert_to_audio_ne(train_set_path,'Train')
! bash convert_to_audio.sh
# !rm -rf Test_audio_ne
convert_to_audio_ne(test_set_path,'Test')
! bash convert_to_audio.sh

# %%
# train_path='gdrive/MyDrive/Audio_TFM/Train_audio_ne/'
# test_path='gdrive/MyDrive/Audio_TFM/Test_audio_ne/'

# %%
train_path='Train_audio_ne/'
test_path='Test_audio_ne/'

# %%
urls_afew_train = glob.glob(pathname=train_path + '*')
urls_afew_test = glob.glob(pathname=test_path + '*')
urls_afew_test[0]
# Out:
# 'Test_audio_ne/000633000.wav'

# %%
print("number of train samples:",len(urls_afew_train))
print("number of test samples:",len(urls_afew_test))
# Out:
# number of train samples: 773
# number of test samples: 381

# %%
emotions=[]
num_samples=[]
for emo in emo_dict.keys():
  samples=list(dict_xy_afew.values()).count(emo)
  num_samples.append(samples)
  emotions.append(emo)
  print("emotion: ", emo)
  print("number of audios: ",samples)
  print("-----")

#Está desbalanceado. Graficamos la distribución por clases:

fig = plt.figure(figsize = (10, 5))
plt.bar(emotions, num_samples, 
        0.35,label="number of samples",color ='blue')
plt.xlabel("emotion classes")
plt.ylabel("No. of samples")
plt.title("Number of samples per emotion in the AFEW dataset")
plt.show()
# Out:
# emotion:  Angry
# number of audios:  197
# -----
# emotion:  Disgust
# number of audios:  113
# -----
# emotion:  Fear
# number of audios:  127
# -----
# emotion:  Happy
# number of audios:  213
# -----
# emotion:  Neutral
# number of audios:  205
# -----
# emotion:  Sad
# number of audios:  177
# -----
# emotion:  Surprise
# number of audios:  120
# -----

# %%
def get_categorical_label(file_id):
  emo=dict_xy_afew[file_id]
  categorical_label=tf.keras.utils.to_categorical(emo_dict[emo], num_classes=num_classes)
  return categorical_label

def get_emo_label(categorical_label):
  emo=dict_xy_afew[file_id]
  return emo

def get_emo_from_categorical(label):
  idx=list(label).index(1)
  return emo_dict_reversed[idx]

def plot_model(history,title):
  fig=plt.figure()
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  # plt.plot(history.history['val_categorical_accuracy'])
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.title("model train and val accuracy "+title)
  
  plt.figure()
  plt.plot(history.history['val_accuracy'])
  plt.title("Validation accuracy " + title)
  plt.show()

def save_plot(history,title,filename="/content/gdrive/My Drive/TFM_MUSI/Audio/Results/"):
  fig = plt.figure()
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  # plt.plot(history.history['val_categorical_accuracy'])
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.title("model train and val accuracy "+title)
  plt.show()
  new_filename  = Path(filename +'/'+title+'.jpg')
  fig.savefig(new_filename, dpi=400, bbox_inches='tight',pad_inches=0)

def plot_conf_matrix(test_set,modelo,path,title,standard_format=True,percentages=True,save_plot=True):
  y_true=test_set.labels
  print(len(y_true))
  labels=[key for key in test_set.class_indices.keys()]
  predictions=modelo.predict(test_set)
  ypred=[round(list(i).index(max(i))) for i in predictions]
  print(confusion_matrix(test_set.classes, ypred)[:,:])
  print("")
  f1=f1_score(y_true, ypred,average=None)
  f1_w=f1_score(y_true, ypred,average='weighted')
  ac=accuracy_score(y_true, ypred)
  print("accuracy: ",ac)
  print("f1 score:",f1)
  print("f1 score weighted:",f1_w)
  print("---------------------------------------------------------")
  print(title)
  if standard_format:

    cm = confusion_matrix(y_true, ypred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues,xticks_rotation='vertical',values_format='d')
    if save_plot:
      plt.savefig(path+".png")
    plt.show()
  print("")
  if standard_format:

    cm = confusion_matrix(y_true, ypred,normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues,xticks_rotation='vertical',values_format='.2f')
    plt.show()
    if save_plot:
      plt.savefig(path+"_perctg.png")
    plt.show()
  print("")

# %%
#Directori per els espectrogrames convertits en imatge
! rm -rf spec_images
os.mkdir('spec_images/')
sets=["train","test"]
for partition in sets:
  os.mkdir('spec_images/'+partition+"/")
  for emotion in emo_dict.keys():
    os.mkdir('spec_images/'+partition+"/"+ emotion)

# %%
#Convertir a spectrograma i guardar como imagen
def create_spectrogram_test(filename,saving_file,preemphasis=False):
    plt.interactive(False)
    audio, sample_rate = librosa.load(filename, sr=None)
    if preemphasis==True: 
      audio=librosa.effects.preemphasis(audio, coef=0.97) #Apply a pre-emphasis filter
    fig = plt.figure(figsize=[0.72,0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    #Espectrograma bàsic:
    S = librosa.feature.melspectrogram(y=audio, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    new_filename  = Path(saving_file + '.jpg')
    fig.savefig(new_filename, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()    
    fig.clf()
    plt.close(fig)
    plt.close('all')

# %%
#Convertir los audios en imágenes de espectrogramas:
for audio_file in urls_afew_test:
  file_id=os.path.split(audio_file)[1].split(".")[0]
  label=dict_xy_afew[file_id]
  saving_file="spec_images/test/"+label+"/"+file_id
  create_spectrogram_test(audio_file,saving_file)

for audio_file in urls_afew_train:
  file_id=os.path.split(audio_file)[1].split(".")[0]
  label=dict_xy_afew[file_id]
  saving_file="spec_images/train/"+label+"/"+file_id
  create_spectrogram_test(audio_file,saving_file)

# %%
train_dir= '/content/spec_images/train'
test_dir= '/content/spec_images/test'
# val_dir= '/content/spec_images/val'

def create_sets(train_dir,test_dir,batch_size):

  datagen=ImageDataGenerator(rescale=1./255.)

  train_generator=datagen.flow_from_directory(
      train_dir,
      batch_size=batch_size,
      seed=42,
      shuffle=True,
      class_mode="categorical",
      classes=["Angry" , "Disgust","Fear" ,"Happy","Neutral" ,"Sad","Surprise"],
      target_size=(64,64))

  # valid_generator=datagen.flow_from_directory(
  #     val_dir,
  #     batch_size=32,
  #     seed=42,
  #     shuffle=True,
  #     class_mode="categorical",
  #     target_size=(64,64))

  test_generator=datagen.flow_from_directory(
      test_dir,
      batch_size=batch_size,
      seed=42,
      shuffle=False,
      class_mode="categorical",
      classes=["Angry" , "Disgust","Fear" ,"Happy","Neutral" ,"Sad","Surprise"],
      target_size=(64,64))
  
  return train_generator,test_generator

train_generator,test_generator=create_sets(train_dir,test_dir,batch_size)
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.

# %%
#Fins aquíí per carregar dades i generar sets

# %%
#Testeamos los 3 modelos con las imágenes de los espectrogramas

# %%
DROPOUT=0.5
l2_regul=0.001
N_OUTPUT_LABELS=7
batch_size=16
epochs=50
# desired_audio_len=131771 # 8997
# preemphasis=False
# normalize=False
num_classes=7
lr=0.0001
input_shape=(64,64,3) 
train_generator,test_generator=create_sets(train_dir,test_dir,batch_size)
# filepath="/content/gdrive/MyDrive/TFM_MUSI/combined_model"
# path=filepath+":{epoch:03d}-val_accuracy:{val_accuracy:.3f}.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# callbacks_list=[checkpoint,E_stopping]
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.

# %%
#Modelo 1: US model:

# %%
#US model
def model1():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), padding='same',
                  input_shape=(64,64,3)))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.5))
  model.add(Conv2D(128, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(128, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.5))
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(7, activation='softmax'))
  return model
audio_model_US=model1()
audio_model_US.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# activation_14 (Activation)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 62, 62, 64)        18496
# _________________________________________________________________
# activation_15 (Activation)   (None, 62, 62, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 31, 31, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 29, 29, 64)        36928
# _________________________________________________________________
# activation_17 (Activation)   (None, 29, 29, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_18 (Activation)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_19 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# activation_20 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 7)                 3591
# =================================================================
# Total params: 2,678,087
# Trainable params: 2,678,087
# Non-trainable params: 0
# _________________________________________________________________

# %%
audio_model_US=model1()

audio_model_US.compile(tf.optimizers.RMSprop(lr=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
E_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=0,patience=15,verbose=1,mode="auto",restore_best_weights=True)
callbacks_list=[E_stopping]

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

history=audio_model_US.fit_generator(generator=train_generator,
                                  steps_per_epoch=STEP_SIZE_TRAIN,
                                  validation_data=test_generator,
                                  validation_steps=STEP_SIZE_TEST,
                                  epochs=60,
                                  callbacks=callbacks_list)
path=""
plot_model(history,"Audio model 1(US) trained with spectrogram images")
title="Audio model 1(US) trained with spectrogram images"
plt.figure()
plot_conf_matrix(test_generator,audio_model_US,path,title,standard_format=True,percentages=True,save_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 48/48 [==============================] - 4s 58ms/step - loss: 1.9438 - accuracy: 0.1546 - val_loss: 1.9876 - val_accuracy: 0.1658
# Epoch 2/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.9264 - accuracy: 0.1783 - val_loss: 1.9259 - val_accuracy: 0.1712
# Epoch 3/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.9210 - accuracy: 0.1836 - val_loss: 1.9220 - val_accuracy: 0.1658
# Epoch 4/60
# 48/48 [==============================] - 2s 48ms/step - loss: 1.9225 - accuracy: 0.1889 - val_loss: 1.9211 - val_accuracy: 0.1712
# Epoch 5/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.9109 - accuracy: 0.1863 - val_loss: 1.9184 - val_accuracy: 0.1739
# Epoch 6/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.9045 - accuracy: 0.2074 - val_loss: 1.8914 - val_accuracy: 0.2337
# Epoch 7/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.8892 - accuracy: 0.2272 - val_loss: 1.8931 - val_accuracy: 0.2065
# Epoch 8/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.8663 - accuracy: 0.2576 - val_loss: 1.8660 - val_accuracy: 0.2310
# Epoch 9/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.8628 - accuracy: 0.2589 - val_loss: 1.8723 - val_accuracy: 0.2174
# Epoch 10/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.8320 - accuracy: 0.2893 - val_loss: 1.8637 - val_accuracy: 0.2201
# Epoch 11/60
# 48/48 [==============================] - 2s 49ms/step - loss: 1.8210 - accuracy: 0.2906 - val_loss: 1.8734 - val_accuracy: 0.2283
# Epoch 12/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.7733 - accuracy: 0.3091 - val_loss: 1.8801 - val_accuracy: 0.2283
# Epoch 13/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.7737 - accuracy: 0.2985 - val_loss: 1.8812 - val_accuracy: 0.2147
# Epoch 14/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.7274 - accuracy: 0.3289 - val_loss: 2.0153 - val_accuracy: 0.1875
# Epoch 15/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.7134 - accuracy: 0.3250 - val_loss: 1.8956 - val_accuracy: 0.2201
# Epoch 16/60
# 48/48 [==============================] - 2s 51ms/step - loss: 1.7108 - accuracy: 0.3435 - val_loss: 1.9018 - val_accuracy: 0.2418
# Epoch 17/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.6555 - accuracy: 0.3659 - val_loss: 1.9511 - val_accuracy: 0.2228
# Epoch 18/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.6137 - accuracy: 0.3831 - val_loss: 1.9516 - val_accuracy: 0.2201
# Epoch 19/60
# 48/48 [==============================] - 2s 51ms/step - loss: 1.5708 - accuracy: 0.3976 - val_loss: 1.9128 - val_accuracy: 0.2228
# Epoch 20/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.5471 - accuracy: 0.4267 - val_loss: 2.0580 - val_accuracy: 0.2255
# Epoch 21/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.5279 - accuracy: 0.4188 - val_loss: 2.0111 - val_accuracy: 0.2283
# Epoch 22/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.4558 - accuracy: 0.4597 - val_loss: 2.0349 - val_accuracy: 0.2310
# Epoch 23/60
# 48/48 [==============================] - 2s 51ms/step - loss: 1.3986 - accuracy: 0.4941 - val_loss: 2.1626 - val_accuracy: 0.2446
# Epoch 24/60
# 48/48 [==============================] - 2s 50ms/step - loss: 1.4470 - accuracy: 0.4518 - val_loss: 2.0671 - val_accuracy: 0.2174
# Epoch 25/60
# 48/48 [==============================] - 2s 51ms/step - loss: 1.3790 - accuracy: 0.4742 - val_loss: 2.1245 - val_accuracy: 0.2473
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# 381
# [[46  0  0 10  5  3  0]
#  [16  0  0 13 10  1  0]
#  [13  0  0 26  6  1  0]
#  [32  0  0 22  8  1  0]
#  [24  1  0 22 12  2  0]
#  [21  0  0 21 18  1  0]
#  [15  0  0 26  3  2  0]]
#
# accuracy:  0.2125984251968504
# f1 score: [0.3982684  0.         0.         0.21674877 0.19512195 0.02777778
#  0.        ]
# f1 score weighted: 0.13842843404673302
# ---------------------------------------------------------
# Audio model 1(US) trained with spectrogram images

# %%
#Modelo 2: Fayek

# %%
def Classifier():
    model = Sequential()

    model.add(Conv2D(filters=16,
                     kernel_size=(10, 10),
                     strides=2,
                     activation='relu',
                     input_shape=input_shape, kernel_regularizer=regularizers.l2(l2_regul)))
    
    model.add(BatchNormalization())

    model.add(Conv2D(filters=32,
                     kernel_size=(10, 10),
                     strides=2,
                     activation='relu',
                     kernel_regularizer=regularizers.l2(l2_regul)))
    
    model.add(BatchNormalization())

    #Afegit això:
    # model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    
    model.add(Dense(units=716,activation='relu'))

    model.add(BatchNormalization())
    model.add(Dropout(DROPOUT))

    model.add(Dense(units=716,activation='relu'))

    model.add(BatchNormalization())
    model.add(Dropout(DROPOUT))

    model.add(Dense(units=716,activation='softmax'))
    
    model.add(BatchNormalization())
    model.add(Dropout(DROPOUT))
    # model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dense(units=N_OUTPUT_LABELS,
                    activation='softmax'))
    return model


audio_model = Classifier()

# %%
audio_model_fayek = Classifier()
E_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=0,patience=15,verbose=1,mode="auto",restore_best_weights=True)
callbacks_list=[E_stopping]

optimizer = tf.keras.optimizers.RMSprop(lr=lr)
audio_model_fayek.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=['categorical_accuracy','accuracy'])

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

history=audio_model_fayek.fit_generator(generator=train_generator,
                                  steps_per_epoch=STEP_SIZE_TRAIN,
                                  validation_data=test_generator,
                                  validation_steps=STEP_SIZE_TEST,
                                  epochs=60,
                                  callbacks=callbacks_list)
path=""
plot_model(history,"Audio model 2(Fayek) trained with spectrogram images")
title="Audio model 2(Fayek) trained with spectrogram images"
plt.figure()
plot_conf_matrix(test_generator,audio_model_fayek,path,title,standard_format=True,percentages=True,save_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 48/48 [==============================] - 5s 51ms/step - loss: 1.9723 - categorical_accuracy: 0.1546 - accuracy: 0.1546 - val_loss: 1.9671 - val_categorical_accuracy: 0.1712 - val_accuracy: 0.1712
# Epoch 2/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.9638 - categorical_accuracy: 0.1704 - accuracy: 0.1704 - val_loss: 1.9637 - val_categorical_accuracy: 0.1712 - val_accuracy: 0.1712
# Epoch 3/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.9404 - categorical_accuracy: 0.2034 - accuracy: 0.2034 - val_loss: 1.9610 - val_categorical_accuracy: 0.1712 - val_accuracy: 0.1712
# Epoch 4/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.9346 - categorical_accuracy: 0.1929 - accuracy: 0.1929 - val_loss: 1.9589 - val_categorical_accuracy: 0.1712 - val_accuracy: 0.1712
# Epoch 5/60
# 48/48 [==============================] - 2s 46ms/step - loss: 1.9306 - categorical_accuracy: 0.2246 - accuracy: 0.2246 - val_loss: 1.9568 - val_categorical_accuracy: 0.1712 - val_accuracy: 0.1712
# Epoch 6/60
# 48/48 [==============================] - 2s 45ms/step - loss: 1.9162 - categorical_accuracy: 0.2497 - accuracy: 0.2497 - val_loss: 1.9545 - val_categorical_accuracy: 0.1685 - val_accuracy: 0.1685
# Epoch 7/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.8800 - categorical_accuracy: 0.2655 - accuracy: 0.2655 - val_loss: 1.9532 - val_categorical_accuracy: 0.1576 - val_accuracy: 0.1576
# Epoch 8/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1
60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.5281 - categorical_accuracy: 0.5007 - accuracy: 0.5007 - val_loss: 1.9075 - val_categorical_accuracy: 0.2283 - val_accuracy: 0.2283
# Epoch 25/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.4638 - categorical_accuracy: 0.5627 - accuracy: 0.5627 - val_loss: 1.9142 - val_categorical_accuracy: 0.2255 - val_accuracy: 0.2255
# Epoch 26/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.3956 - categorical_accuracy: 0.5667 - accuracy: 0.5667 - val_loss: 1.9221 - val_categorical_accuracy: 0.2228 - val_accuracy: 0.2228
# Epoch 27/60
# 48/48 [==============================] - 2s 45ms/step - loss: 1.3428 - categorical_accuracy: 0.6143 - accuracy: 0.6143 - val_loss: 1.9144 - val_categorical_accuracy: 0.2446 - val_accuracy: 0.2446
# Epoch 28/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.3270 - categorical_accuracy: 0.6143 - accuracy: 0.6143 - val_loss: 1.9144 - val_categorical_accuracy: 0.2337 - val_accuracy: 0.2337
# Epoch 29/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.2672 - categorical_accuracy: 0.6724 - accuracy: 0.6724 - val_loss: 1.9495 - val_categorical_accuracy: 0.1957 - val_accuracy: 0.1957
# Epoch 30/60
# 48/48 [==============================] - 2s 45ms/step - loss: 1.2188 - categorical_accuracy: 0.6777 - accuracy: 0.6777 - val_loss: 1.9302 - val_categorical_accuracy: 0.2500 - val_accuracy: 0.2500
# Epoch 31/60
# 48/48 [==============================] - 2s 45ms/step - loss: 1.1363 - categorical_accuracy: 0.7041 - accuracy: 0.7041 - val_loss: 1.9501 - val_categorical_accuracy: 0.2255 - val_accuracy: 0.2255
# Epoch 32/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.0854 - categorical_accuracy: 0.7358 - accuracy: 0.7358 - val_loss: 1.9798 - val_categorical_accuracy: 0.2092 - val_accuracy: 0.2092
# Epoch 33/60
# 48/48 [==============================] - 2s 44ms/step - loss: 1.0438 - categorical_accuracy: 0.7371 - accuracy: 0.7371 - val_loss: 1.9649 - val_categorical_accuracy: 0.2337 - val_accuracy: 0.2337
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 381
# [[25  0  0 17 13  9  0]
#  [ 5  0  0 18 15  2  0]
#  [ 4  0  4 16 20  2  0]
#  [ 7  0  5 21 27  3  0]
#  [ 6  0  0 21 32  2  0]
#  [11  0  0 21 28  1  0]
#  [ 4  0  1 18 19  4  0]]
#
# accuracy:  0.2178477690288714
# f1 score: [0.3968254  0.         0.14285714 0.21538462 0.29767442 0.02380952
#  0.        ]
# f1 score weighted: 0.170992139697505
# ---------------------------------------------------------
# Audio model 2(Fayek) trained with spectrogram images

# %%
# modelo 3: VGG16 fine-tuning last conv block

# %%
def create_model(num_frozen_layers=8,dropout=None):
  model = VGG16(include_top=False,weights="imagenet", input_shape=(img_width, img_height, 3))
  print("VGG_summary:")
  # model.summary()
  # add new classifier layers
  flat1 = Flatten()(model.layers[-1].output)
  dense1 = Dense(1024, activation='relu')(flat1)
  if dropout!=None:
    dropout=Dropout(dropout)(dense1)
    output = Dense(7, activation='softmax')(dropout)
  else:
    output = Dense(7, activation='softmax')(dense1)
  # define new model
  new_model = Model(inputs=model.inputs, outputs=output)
  print(new_model.layers)
  for layer in new_model.layers[0:-8]:
    print("freezing layer: ",layer.name)
    layer.trainable = False
  print("new_model summary!")
  new_model.summary()
  return new_model

model_VGG_audio=create_model(8,dropout=0.5)
# Out:
# VGG_summary:
# [<keras.engine.input_layer.InputLayer object at 0x7f479c2c9390>, <keras.layers.convolutional.Conv2D object at 0x7f479c388110>, <keras.layers.convolutional.Conv2D object at 0x7f48179dc4d0>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c388090>, <keras.layers.convolutional.Conv2D object at 0x7f479c343410>, <keras.layers.convolutional.Conv2D object at 0x7f479c2ebe90>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c2dd810>, <keras.layers.convolutional.Conv2D object at 0x7f479c2f3610>, <keras.layers.convolutional.Conv2D object at 0x7f479c2e9950>, <keras.layers.convolutional.Conv2D object at 0x7f479c2d94d0>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c303850>, <keras.layers.convolutional.Conv2D object at 0x7f479c2fb210>, <keras.layers.convolutional.Conv2D object at 0x7f479c2ecd10>, <keras.layers.convolutional.Conv2D object at 0x7f479c304210>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c297050>, <keras.layers.convolutional.Conv2D object at 0x7f479c297a90>, <keras.layers.convolutional.Conv2D object at 0x7f479c2f9210>, <keras.layers.convolutional.Conv2D object at 0x7f479c292150>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c2a6110>, <keras.layers.core.Flatten object at 0x7f479c3042d0>, <keras.layers.core.Dense object at 0x7f479c304650>, <keras.layers.core.Dropout object at 0x7f481008bd10>, <keras.layers.core.Dense object at 0x7f479c2ae690>]
# freezing layer:  input_5
# freezing layer:  block1_conv1
# freezing layer:  block1_conv2
# freezing layer:  block1_pool
# freezing layer:  block2_conv1
# freezing layer:  block2_conv2
# freezing layer:  block2_pool
# freezing layer:  block3_conv1
# freezing layer:  block3_conv2
# freezing layer:  block3_conv3
# freezing layer:  block3_pool
# freezing layer:  block4_conv1
# freezing layer:  block4_conv2
# freezing layer:  block4_conv3
# freezing layer:  block4_pool
# new_model summary!
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 7)                 7175
# =================================================================
# Total params: 16,820,039
# Trainable params: 9,184,775
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
model3.compile(loss='categorical_crossentropy',
                optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                metrics=['accuracy','categorical_accuracy'])


path=filepath+"VGGTEST"+":{epoch:03d}-val_accuracy:{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

E_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                              min_delta=0,
                                              patience=30,
                                              verbose=1,
                                              mode="auto",
                                              restore_best_weights=True)
  # WandbCallbacks=WandbCallback(
  #               monitor='val_loss',
  #               verbose=1,
  #               mode='auto',
  #               generator=test_set,
  #               validation_steps=nb_test_samples // batch_size,
  #               input_type="image",
  #               labels=['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise'])

callbacks_list = [checkpoint,E_stopping]


STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
history=model3.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_TEST,
                    epochs=100,
                    callbacks=callback_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 24/24 [==============================] - 5s 108ms/step - loss: 2.1293 - accuracy: 0.1486 - categorical_accuracy: 0.1486 - val_loss: 1.9401 - val_accuracy: 0.1591 - val_categorical_accuracy: 0.1591
#
# Epoch 00001: val_accuracy did not improve from 0.26136
# Epoch 2/100
# 24/24 [==============================] - 2s 66ms/step - loss: 2.0099 - accuracy: 0.1588 - categorical_accuracy: 0.1588 - val_loss: 1.9177 - val_accuracy: 0.2131 - val_categorical_accuracy: 0.2131
#
# Epoch 00002: val_accuracy did not improve from 0.26136
# Epoch 3/100
# 24/24 [==============================] - 2s 66ms/step - loss: 2.0197 - accuracy: 0.2055 - categorical_accuracy: 0.2055 - val_loss: 1.9105 - val_accuracy: 0.2017 - val_categorical_accuracy: 0.2017
#
# Epoch 00003: val_accuracy did not improve from 0.26136
# Epoch 4/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.9781 - accuracy: 0.2390 - categorical_accuracy: 0.2390 - val_loss: 1.9058 - val_accuracy: 0.2216 - val_categorical_accuracy: 0.2216
#
# Epoch 00004: val_accuracy did not improve from 0.26136
# Epoch 5/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.9326 - accuracy: 0.2008 - categorical_accuracy: 0.2008 - val_loss: 1.9027 - val_accuracy: 0.2188 - val_categorical_accuracy: 0.2188
#
# Epoch 00005: val_accuracy did not improve from 0.26136
# Epoch 6/100
# 24/24 [==============================] - 1s 64ms/step - loss: 1.9808 - accuracy: 0.1924 - categorical_accuracy: 0.1924 - val_loss: 1.8772 - val_accuracy: 0.2244 - val_categorical_accuracy: 0.2244
#
# Epoch 00006: val_accuracy did not improve from 0.26136
# Epoch 7/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.9259 - accuracy: 0.2112 - categorical_accuracy: 0.2112 - val_loss: 1.8942 - val_accuracy: 0.2358 - val_categorical_accuracy: 0.2358
#
# Epoch 00007: val_accuracy did not improve from 0.26136
# Epoch 8/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.8974 - accuracy: 0.2363 - categorical_accuracy: 0.2363 - val_loss: 1.8676 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00008: val_accuracy improved from 0.26136 to 0.27273, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 9/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.8464 - accuracy: 0.2727 - categorical_accuracy: 0.2727 - val_loss: 1.8698 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00009: val_accuracy improved from 0.27273 to 0.27557, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 10/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.8453 - accuracy: 0.2866 - categorical_accuracy: 0.2866 - val_loss: 1.8610 - val_accuracy: 0.2528 - val_categorical_accuracy: 0.2528
#
# Epoch 00010: val_accuracy did not improve from 0.27557
# Epoch 11/100
# 24/24 [==============================] - 1s 64ms/step - loss: 1.8390 - accuracy: 0.2727 - categorical_accuracy: 0.2727 - val_loss: 1.8482 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
#
# Epoch 00011: val_accuracy did not improve from 0.27557
# Epoch 12/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.8099 - accuracy: 0.2779 - categorical_accuracy: 0.2779 - val_loss: 1.8447 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00012: val_accuracy did not improve from 0.27557
# Epoch 13/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.8110 - accuracy: 0.2985 - categorical_accuracy: 0.2985 - val_loss: 1.8568 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
#
# Epoch 00013: val_accuracy did not improve from 0.27557
# Epoch 14/100
# 24/24 [==============================] - 2s 73ms/step - loss: 1.8503 - accuracy: 0.2671 - categorical_accuracy: 0.2671 - val_loss: 1.8460 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00014: val_accuracy did not improve from 0.27557
# Epoch 15/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.8242 - accuracy: 0.2896 - categorical_accuracy: 0.2896 - val_loss: 1.8570 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00015: val_accuracy did not improve from 0.27557
# Epoch 16/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.7440 - accuracy: 0.3150 - categorical_accuracy: 0.3150 - val_loss: 1.8456 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00016: val_accuracy did not improve from 0.27557
# Epoch 17/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.7303 - accuracy: 0.3434 - categorical_accuracy: 0.3434 - val_loss: 1.8419 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00017: val_accuracy did not improve from 0.27557
# Epoch 18/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.7208 - accuracy: 0.3271 - categorical_accuracy: 0.3271 - val_loss: 1.8412 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00018: val_accuracy did not improve from 0.27557
# Epoch 19/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.7258 - accuracy: 0.3707 - categorical_accuracy: 0.3707 - val_loss: 1.8305 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00019: val_accuracy improved from 0.27557 to 0.28409, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 20/100
# 24/24 [==============================] - 2s 69ms/step - loss: 1.7345 - accuracy: 0.3411 - categorical_accuracy: 0.3411 - val_loss: 1.8302 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00020: val_accuracy did not improve from 0.28409
# Epoch 21/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.6924 - accuracy: 0.3514 - categorical_accuracy: 0.3514 - val_loss: 1.8374 - val_accuracy: 0.2557 - val_categorical_accuracy: 0.2557
#
# Epoch 00021: val_accuracy did not improve from 0.28409
# Epoch 22/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6890 - accuracy: 0.3419 - categorical_accuracy: 0.3419 - val_loss: 1.8465 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00022: val_accuracy did not improve from 0.28409
# Epoch 23/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.7189 - accuracy: 0.3387 - categorical_accuracy: 0.3387 - val_loss: 1.8322 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00023: val_accuracy did not improve from 0.28409
# Epoch 24/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.6878 - accuracy: 0.3526 - categorical_accuracy: 0.3526 - val_loss: 1.8540 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00024: val_accuracy did not improve from 0.28409
# Epoch 25/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.6879 - accuracy: 0.3290 - categorical_accuracy: 0.3290 - val_loss: 1.8231 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00025: val_accuracy did not improve from 0.28409
# Epoch 26/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.6884 - accuracy: 0.3133 - categorical_accuracy: 0.3133 - val_loss: 1.8329 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
#
# Epoch 00026: val_accuracy improved from 0.28409 to 0.28977, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 27/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.6600 - accuracy: 0.3473 - categorical_accuracy: 0.3473 - val_loss: 1.8496 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00027: val_accuracy did not improve from 0.28977
# Epoch 28/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6684 - accuracy: 0.3476 - categorical_accuracy: 0.3476 - val_loss: 1.8340 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00028: val_accuracy did not improve from 0.28977
# Epoch 29/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6104 - accuracy: 0.3773 - categorical_accuracy: 0.3773 - val_loss: 1.8422 - val_accuracy: 0.2528 - val_categorical_accuracy: 0.2528
#
# Epoch 00029: val_accuracy did not improve from 0.28977
# Epoch 30/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6236 - accuracy: 0.3664 - categorical_accuracy: 0.3664 - val_loss: 1.8520 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
#
# Epoch 00030: val_accuracy did not improve from 0.28977
# Epoch 31/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.6181 - accuracy: 0.3857 - categorical_accuracy: 0.3857 - val_loss: 1.8383 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00031: val_accuracy did not improve from 0.28977
# Epoch 32/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.6105 - accuracy: 0.3940 - categorical_accuracy: 0.3940 - val_loss: 1.8471 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00032: val_accuracy did not improve from 0.28977
# Epoch 33/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.6302 - accuracy: 0.3669 - categorical_accuracy: 0.3669 - val_loss: 1.8363 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00033: val_accuracy did not improve from 0.28977
# Epoch 34/100
# 24/24 [==============================] - 2s 74ms/step - loss: 1.6338 - accuracy: 0.3942 - categorical_accuracy: 0.3942 - val_loss: 1.8524 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00034: val_accuracy did not improve from 0.28977
# Epoch 35/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.5642 - accuracy: 0.4031 - categorical_accuracy: 0.4031 - val_loss: 1.8545 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00035: val_accuracy did not improve from 0.28977
# Epoch 36/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.6532 - accuracy: 0.3888 - categorical_accuracy: 0.3888 - val_loss: 1.8328 - val_accuracy: 0.2784 - val_categorical_accuracy: 0.2784
#
# Epoch 00036: val_accuracy did not improve from 0.28977
# Epoch 37/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.5460 - accuracy: 0.4348 - categorical_accuracy: 0.4348 - val_loss: 1.8490 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00037: val_accuracy did not improve from 0.28977
# Epoch 38/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5362 - accuracy: 0.4369 - categorical_accuracy: 0.4369 - val_loss: 1.8321 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00038: val_accuracy did not improve from 0.28977
# Epoch 39/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5879 - accuracy: 0.3976 - categorical_accuracy: 0.3976 - val_loss: 1.8432 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00039: val_accuracy did not improve from 0.28977
# Epoch 40/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.5638 - accuracy: 0.4292 - categorical_accuracy: 0.4292 - val_loss: 1.8243 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00040: val_accuracy did not improve from 0.28977
# Epoch 41/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.5481 - accuracy: 0.4517 - categorical_accuracy: 0.4517 - val_loss: 1.8418 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00041: val_accuracy did not improve from 0.28977
# Epoch 42/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5664 - accuracy: 0.3926 - categorical_accuracy: 0.3926 - val_loss: 1.8445 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00042: val_accuracy did not improve from 0.28977
# Epoch 43/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.5437 - accuracy: 0.4107 - categorical_accuracy: 0.4107 - val_loss: 1.8436 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00043: val_accuracy did not improve from 0.28977
# Epoch 44/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.5069 - accuracy: 0.4463 - categorical_accuracy: 0.4463 - val_loss: 1.8609 - val_accuracy: 0.2983 - val_categorical_accuracy: 0.2983
#
# Epoch 00044: val_accuracy improved from 0.28977 to 0.29830, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 45/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.5211 - accuracy: 0.4351 - categorical_accuracy: 0.4351 - val_loss: 1.8621 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00045: val_accuracy did not improve from 0.29830
# Epoch 46/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5186 - accuracy: 0.4222 - categorical_accuracy: 0.4222 - val_loss: 1.8380 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
#
# Epoch 00046: val_accuracy did not improve from 0.29830
# Epoch 47/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.5287 - accuracy: 0.4250 - categorical_accuracy: 0.4250 - val_loss: 1.8854 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
#
# Epoch 00047: val_accuracy did not improve from 0.29830
# Epoch 48/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4741 - accuracy: 0.4498 - categorical_accuracy: 0.4498 - val_loss: 1.8585 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00048: val_accuracy did not improve from 0.29830
# Epoch 49/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.4858 - accuracy: 0.4761 - categorical_accuracy: 0.4761 - val_loss: 1.8910 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00049: val_accuracy did not improve from 0.29830
# Epoch 50/100
# 24/24 [==============================] - 2s 69ms/step - loss: 1.4445 - accuracy: 0.4954 - categorical_accuracy: 0.4954 - val_loss: 1.8349 - val_accuracy: 0.2869 - val_categorical_accuracy: 0.2869
#
# Epoch 00050: val_accuracy did not improve from 0.29830
# Epoch 51/100
# 24/24 [==============================] - 2s 77ms/step - loss: 1.4373 - accuracy: 0.4925 - categorical_accuracy: 0.4925 - val_loss: 1.8448 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00051: val_accuracy did not improve from 0.29830
# Epoch 52/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.4901 - accuracy: 0.4508 - categorical_accuracy: 0.4508 - val_loss: 1.8847 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00052: val_accuracy did not improve from 0.29830
# Epoch 53/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.4377 - accuracy: 0.4799 - categorical_accuracy: 0.4799 - val_loss: 1.8736 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00053: val_accuracy did not improve from 0.29830
# Epoch 54/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.4733 - accuracy: 0.4513 - categorical_accuracy: 0.4513 - val_loss: 1.8746 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00054: val_accuracy did not improve from 0.29830
# Epoch 55/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.4210 - accuracy: 0.4990 - categorical_accuracy: 0.4990 - val_loss: 1.8789 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
#
# Epoch 00055: val_accuracy did not improve from 0.29830
# Epoch 56/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.3913 - accuracy: 0.4800 - categorical_accuracy: 0.4800 - val_loss: 1.8661 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00056: val_accuracy did not improve from 0.29830
# Epoch 57/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.4129 - accuracy: 0.4886 - categorical_accuracy: 0.4886 - val_loss: 1.8711 - val_accuracy: 0.2784 - val_categorical_accuracy: 0.2784
#
# Epoch 00057: val_accuracy did not improve from 0.29830
# Epoch 58/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4479 - accuracy: 0.4623 - categorical_accuracy: 0.4623 - val_loss: 1.8814 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00058: val_accuracy did not improve from 0.29830
# Epoch 59/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.4209 - accuracy: 0.4931 - categorical_accuracy: 0.4931 - val_loss: 1.8840 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00059: val_accuracy did not improve from 0.29830
# Epoch 60/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.3953 - accuracy: 0.4829 - categorical_accuracy: 0.4829 - val_loss: 1.8629 - val_accuracy: 0.2557 - val_categorical_accuracy: 0.2557
#
# Epoch 00060: val_accuracy did not improve from 0.29830
# Epoch 61/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.3943 - accuracy: 0.5026 - categorical_accuracy: 0.5026 - val_loss: 1.8689 - val_accuracy: 0.2557 - val_categorical_accuracy: 0.2557
#
# Epoch 00061: val_accuracy did not improve from 0.29830
# Epoch 62/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3568 - accuracy: 0.5152 - categorical_accuracy: 0.5152 - val_loss: 1.8723 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
#
# Epoch 00062: val_accuracy did not improve from 0.29830
# Epoch 63/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3790 - accuracy: 0.5053 - categorical_accuracy: 0.5053 - val_loss: 1.8630 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00063: val_accuracy did not improve from 0.29830
# Epoch 64/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3853 - accuracy: 0.5016 - categorical_accuracy: 0.5016 - val_loss: 1.9150 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
#
# Epoch 00064: val_accuracy did not improve from 0.29830
# Epoch 65/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.3462 - accuracy: 0.5019 - categorical_accuracy: 0.5019 - val_loss: 1.8882 - val_accuracy: 0.2443 - val_categorical_accuracy: 0.2443
#
# Epoch 00065: val_accuracy did not improve from 0.29830
# Epoch 66/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3732 - accuracy: 0.5179 - categorical_accuracy: 0.5179 - val_loss: 1.9148 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00066: val_accuracy did not improve from 0.29830
# Epoch 67/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.3148 - accuracy: 0.5017 - categorical_accuracy: 0.5017 - val_loss: 1.9052 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00067: val_accuracy did not improve from 0.29830
# Epoch 68/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3076 - accuracy: 0.5294 - categorical_accuracy: 0.5294 - val_loss: 1.8777 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00068: val_accuracy did not improve from 0.29830
# Epoch 69/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3019 - accuracy: 0.5459 - categorical_accuracy: 0.5459 - val_loss: 1.8823 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
#
# Epoch 00069: val_accuracy did not improve from 0.29830
# Epoch 70/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.2748 - accuracy: 0.5262 - categorical_accuracy: 0.5262 - val_loss: 1.8772 - val_accuracy: 0.3068 - val_categorical_accuracy: 0.3068
#
# Epoch 00070: val_accuracy improved from 0.29830 to 0.30682, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 71/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.2383 - accuracy: 0.5845 - categorical_accuracy: 0.5845 - val_loss: 1.9006 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00071: val_accuracy did not improve from 0.30682
# Epoch 72/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.2846 - accuracy: 0.5235 - categorical_accuracy: 0.5235 - val_loss: 1.8941 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00072: val_accuracy did not improve from 0.30682
# Epoch 73/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.2333 - accuracy: 0.6109 - categorical_accuracy: 0.6109 - val_loss: 1.9355 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
#
# Epoch 00073: val_accuracy did not improve from 0.30682
# Epoch 74/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.2424 - accuracy: 0.5596 - categorical_accuracy: 0.5596 - val_loss: 1.9407 - val_accuracy: 0.2585 - val_categorical_accuracy: 0.2585
#
# Epoch 00074: val_accuracy did not improve from 0.30682
# Epoch 75/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3175 - accuracy: 0.5248 - categorical_accuracy: 0.5248 - val_loss: 1.9061 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00075: val_accuracy did not improve from 0.30682
# Epoch 76/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.3170 - accuracy: 0.5330 - categorical_accuracy: 0.5330 - val_loss: 1.8917 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00076: val_accuracy did not improve from 0.30682
# Epoch 77/100
# 24/24 [==============================] - 2s 73ms/step - loss: 1.2022 - accuracy: 0.6016 - categorical_accuracy: 0.6016 - val_loss: 1.9551 - val_accuracy: 0.2557 - val_categorical_accuracy: 0.2557
#
# Epoch 00077: val_accuracy did not improve from 0.30682
# Epoch 78/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.2329 - accuracy: 0.5752 - categorical_accuracy: 0.5752 - val_loss: 1.9170 - val_accuracy: 0.2926 - val_categorical_accuracy: 0.2926
#
# Epoch 00078: val_accuracy did not improve from 0.30682
# Epoch 79/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.1846 - accuracy: 0.6045 - categorical_accuracy: 0.6045 - val_loss: 1.9162 - val_accuracy: 0.2614 - val_categorical_accuracy: 0.2614
#
# Epoch 00079: val_accuracy did not improve from 0.30682
# Epoch 80/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.2080 - accuracy: 0.5949 - categorical_accuracy: 0.5949 - val_loss: 1.9052 - val_accuracy: 0.3068 - val_categorical_accuracy: 0.3068
#
# Epoch 00080: val_accuracy did not improve from 0.30682
# Epoch 81/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1791 - accuracy: 0.6005 - categorical_accuracy: 0.6005 - val_loss: 1.9489 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00081: val_accuracy did not improve from 0.30682
# Epoch 82/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.2270 - accuracy: 0.5567 - categorical_accuracy: 0.5567 - val_loss: 1.8963 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00082: val_accuracy did not improve from 0.30682
# Epoch 83/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1527 - accuracy: 0.6127 - categorical_accuracy: 0.6127 - val_loss: 1.9473 - val_accuracy: 0.2983 - val_categorical_accuracy: 0.2983
#
# Epoch 00083: val_accuracy did not improve from 0.30682
# Epoch 84/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.1888 - accuracy: 0.5959 - categorical_accuracy: 0.5959 - val_loss: 1.9215 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00084: val_accuracy did not improve from 0.30682
# Epoch 85/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1293 - accuracy: 0.6151 - categorical_accuracy: 0.6151 - val_loss: 1.9224 - val_accuracy: 0.3040 - val_categorical_accuracy: 0.3040
#
# Epoch 00085: val_accuracy did not improve from 0.30682
# Epoch 86/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1172 - accuracy: 0.6316 - categorical_accuracy: 0.6316 - val_loss: 1.9432 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00086: val_accuracy did not improve from 0.30682
# Epoch 87/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.1594 - accuracy: 0.5964 - categorical_accuracy: 0.5964 - val_loss: 1.9148 - val_accuracy: 0.2926 - val_categorical_accuracy: 0.2926
#
# Epoch 00087: val_accuracy did not improve from 0.30682
# Epoch 88/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1424 - accuracy: 0.6373 - categorical_accuracy: 0.6373 - val_loss: 1.9474 - val_accuracy: 0.2670 - val_categorical_accuracy: 0.2670
#
# Epoch 00088: val_accuracy did not improve from 0.30682
# Epoch 89/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1583 - accuracy: 0.5885 - categorical_accuracy: 0.5885 - val_loss: 1.9288 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00089: val_accuracy did not improve from 0.30682
# Epoch 90/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.1128 - accuracy: 0.6402 - categorical_accuracy: 0.6402 - val_loss: 1.9511 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00090: val_accuracy did not improve from 0.30682
# Epoch 91/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0951 - accuracy: 0.6589 - categorical_accuracy: 0.6589 - val_loss: 1.9828 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
#
# Epoch 00091: val_accuracy did not improve from 0.30682
# Epoch 92/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1467 - accuracy: 0.6030 - categorical_accuracy: 0.6030 - val_loss: 2.0194 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
#
# Epoch 00092: val_accuracy did not improve from 0.30682
# Epoch 93/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0787 - accuracy: 0.6407 - categorical_accuracy: 0.6407 - val_loss: 1.9730 - val_accuracy: 0.2528 - val_categorical_accuracy: 0.2528
#
# Epoch 00093: val_accuracy did not improve from 0.30682
# Epoch 94/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0766 - accuracy: 0.6157 - categorical_accuracy: 0.6157 - val_loss: 1.9423 - val_accuracy: 0.2983 - val_categorical_accuracy: 0.2983
#
# Epoch 00094: val_accuracy did not improve from 0.30682
# Epoch 95/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0729 - accuracy: 0.6468 - categorical_accuracy: 0.6468 - val_loss: 1.9494 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
#
# Epoch 00095: val_accuracy did not improve from 0.30682
# Epoch 96/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.0623 - accuracy: 0.6579 - categorical_accuracy: 0.6579 - val_loss: 1.9757 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
#
# Epoch 00096: val_accuracy did not improve from 0.30682
# Epoch 97/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0677 - accuracy: 0.6214 - categorical_accuracy: 0.6214 - val_loss: 1.9852 - val_accuracy: 0.2926 - val_categorical_accuracy: 0.2926
#
# Epoch 00097: val_accuracy did not improve from 0.30682
# Epoch 98/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0213 - accuracy: 0.6494 - categorical_accuracy: 0.6494 - val_loss: 1.9894 - val_accuracy: 0.2926 - val_categorical_accuracy: 0.2926
#
# Epoch 00098: val_accuracy did not improve from 0.30682
# Epoch 99/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.9986 - accuracy: 0.6950 - categorical_accuracy: 0.6950 - val_loss: 2.0011 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
#
# Epoch 00099: val_accuracy did not improve from 0.30682
# Epoch 100/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0227 - accuracy: 0.6582 - categorical_accuracy: 0.6582 - val_loss: 1.9918 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
#
# Epoch 00100: val_accuracy did not improve from 0.30682

# %%
plot_model(history,"model imatges specs vgg16 EMOTIW_audio_to_image arquitectura Urbansound")
plt.figure()

# %%
model3.save("/content/gdrive/MyDrive/TFM_MUSI/combined_model/model3imatgespecsVGG16.h5")

# %%
model3=keras.models.load_model("/content/gdrive/MyDrive/TFM_MUSI/combined_model/model3imatgespecsVGG16.h5")

# %%
plot_conf_matrix(test_generator,model3,path,title,standard_format=True,percentages=True,save_plot=True)
# Out:
# 381
# [[31  3  1 22  3  4  0]
#  [ 8  6  1 13  4  8  0]
#  [ 8  2  9 16  4  4  3]
#  [10  6  6 26  5  9  1]
#  [10  4  2 26 15  4  0]
#  [ 7  5  8 16  7 13  5]
#  [ 6  1  4 18  7  5  5]]
#
# accuracy:  0.2755905511811024
# f1 score: [0.43055556 0.17910448 0.23376623 0.26       0.28301887 0.24074074
#  0.16666667]
# f1 score weighted: 0.26632279319823626
# ---------------------------------------------------------
# vgg16 last conv block fine-tuned audio spectrogram images

# %%
#Load model and save predictions:

# %%
audio_vgg_model=keras.models.load_model("/content/gdrive/MyDrive/TFM_MUSI/combined_model/model3imatgespecsVGG16.h5")

# %%
from keras.preprocessing.image import img_to_array
vgg_audio_model_preds_test={}
dir= "/content/spec_images/test/"

for emotion in os.listdir(dir):
  emotion_label=emotion
  for img_path in glob.glob(dir+emotion+"/*"):
    video_id= img_path.split("/")[-1].split(".")[0]
    
    # print(video_id)
    img=tf.keras.preprocessing.image.load_img(img_path, color_mode="rgb",target_size=(64,64))
    x = img_to_array(img)
    x=x/255.
    # new_x=tf.expand_dims(x, axis=0)
    input = np.array([x]) 
    y=audio_vgg_model.predict(input)
    vgg_audio_model_preds_test[video_id]=y
      # print(y)

# %%
a_file = open("vgg_audio_model_preds_train.pkl", "rb")
output = pickle.load(a_file)

# print(output)
print(output.keys())
output["000149120"]
# Out:
# dict_keys(['005013327', '003634414', '002221960', '002631920', '002842814', '003127040', '010301054', '005153760', '000407350', '004438800', '001635160', '002516320', '001802480', '011306940', '000256440', '001641600', '005951680', '001404920', '001817880', '000419314', '002408334', '004944560', '001134360', '004020574', '005826400', '005515200', '011329120', '002934807', '001012520', '001653480', '000123880', '002650134', '001636600', '012535447', '010255520', '014527960', '001850640', '004406878', '003902287', '000758680', '004511694', '004025454', '004524480', '004141320', '015646720', '012246840', '000403327', '010316167', '001130680', '014246120', '001010160', '001422600', '013036534', '005122167', '011810688', '002137920', '002607280', '003033040', '010212354', '001100640', '000404000', '003555207', '002809954', '010732287', '001748200', '005805120', '011409414', '004415287', '001949614', '011434920', '000147200', '013818854', '012949687', '011411334', '002441440', '001703120', '005112360', '002512120', '010158520', '000322600', '005450438', '004104894', '014206395', '010527560', '014135480', '005242454', '004436174', '002730640', '001537920', '005817960', '013418800', '011309840', '005602326', '005421560', '005814807', '000423127', '002100360', '000423240', '000752320', '010318047', '001001280', '012439174', '000329320', '011111488', '005457920', '000451280', '011959447', '003318600', '003636440', '001702480', '013037520', '004512014', '005618320', '003353294', '011000040', '004743240', '011302920', '012215600', '004514600', '000316560', '004540840', '004737840', '005730814', '005020720', '004417618', '012246400', '012532520', '011504520', '003400720', '001108440', '012553854', '005150814', '004912374', '000929080', '005948960', '013507254', '003314000', '012224880', '004532760', '003314887', '003812174', '000149120', '005828120', '011256120', '004713680', '004635847', '014928240', '021837840', '002033320', '010220693', '001855040', '004238120', '011506880', '012239520', '002336640', '003323120', '004056050', '004556200', '001247040', '004521040', '013508360', '003207280', '003326254', '004601840', '013159920', '013602654', '014127400', '010233320', '004739560', '005646000', '000551374', '003123200', '005806334', '011323560', '000439654', '012331168', '000753440', '013335080', '002801320', '010911400', '000831400', '000446654', '001507520', '003652360', '000543854', '004650278', '004017880', '001727400', '002938280', '003814280', '011957400', '014936360', '014029720', '004840160', '012651280', '002655360', '014013000', '010944320', '001912000', '004008240', '001446480', '004643134', '005936774', '013745000', '013431600', '010958154', '013338000', '012715354', '001802800', '014622680', '003443960', '014017760', '012751395', '000613480', '002709240', '003502854', '003904000', '002145120', '010730200', '000800640', '010517640', '000750480', '013432750', '005513240', '000919327', '012255920', '001201800', '001817054', '000215738', '000803520', '011018760', '000505720', '012910760', '000946654', '000647360', '005405240', '001013367', '013139640', '001103160', '011901800', '002239440', '012401520', '010507927', '011928240', '011553514', '001444527', '011535834', '005307640', '013852920', '011538834', '002916200', '002259807', '011602240', '011403440', '005700400', '005026400', '005859040', '003024767', '012705800', '010948367', '015238600', '014735000', '004041920', '011401160', '013523600', '011005340', '011440640', '011006040', '011543240', '011312320', '010715720', '013609600', '001713280', '014424874', '005711000', '000941320', '013104000', '010622447', '005437600', '011341440', '004039607', '005023200', '013714720', '010552367', '010741680', '011131080', '005329500', '011616534', '000943680', '010320007', '010025312', '011823760', '010854607', '015626280', '010010080', '010024680', '001016054', '004115287', '010805134', '000142325', '005532334', '004540080', '015145521', '001731150', '001411927', '000606007', '010904207' ...
# array([[0.60835004, 0.01976722, 0.03364116, 0.14789636, 0.00358232,
#         0.0755593 , 0.11120356]], dtype=float32)

# %%
import pickle
a_file = open("vgg_audio_model_preds_train.pkl", "wb")
pickle.dump(vgg_audio_model_preds_train, a_file)
a_file.close()

# %%
from keras.preprocessing.image import img_to_array
vgg_audio_model_preds_train={}
dir= "/content/spec_images/train/"
for emotion in os.listdir(dir):
  emotion_label=emotion
  for img_path in glob.glob(dir+emotion+"/*"):
    video_id= img_path.split("/")[-1].split(".")[0]
    
    print(video_id)
    img=tf.keras.preprocessing.image.load_img(img_path, color_mode="rgb",target_size=(64,64))
    x = img_to_array(img)
    x=x/255.
    # new_x=tf.expand_dims(x, axis=0)
    input = np.array([x]) 
    y=audio_vgg_model.predict(input)
    vgg_audio_model_preds_train[video_id]=y
      # print(y)
# Out:
# 000455174
# 001759754
# 010123320
# 003343120
# 001548120
# 011809840
# 012101720
# 011603980
# 003723054
# 000643974
# 014003120
# 005153760
# 000945960
# 001905680
#  '014429160': array([[0.05513472, 0.23402588, 0.05854667, 0.26095662, 0.18420999,
#          0.10019579, 0.10693029]], dtype=float32),
#  '014525280': array([[0.10086879, 0.04492679, 0.00715844, 0.13518094, 0.00479623,
#          0.680265  , 0.02680378]], dtype=float32),
#  '014611480': array([[0.00480919, 0.03078949, 0.02376142, 0.0310905 , 0.04268835,
#          0.8120295 , 0.0548315 ]], dtype=float32),
#  '014643120': array([[0.04480701, 0.12639293, 0.15613149, 0.12453165, 0.11152739,
#          0.29737037, 0.13923916]], dtype=float32),
#  '014709480': array([[0.01714867, 0.08493191, 0.02246168, 0.46751502, 0.0402634 ,
#          0.33382112, 0.0338582 ]], dtype=float32),
#  '014824160': array([[0.04450205, 0.44933236, 0.01212959, 0.09487021, 0.32916176,
#          0.0428044 , 0.02719963]], dtype=float32),
#  '014923560': array([[0.017482  , 0.0558386 , 0.01493143, 0.6742217 , 0.05909315,
#          0.11568733, 0.06274581]], dtype=float32),
#  '015020000': array([[0.25807902, 0.01746135, 0.03300449, 0.33003312, 0.02156026,
#          0.08809238, 0.25176936]], dtype=float32),
#  '015143720': array([[0.05191129, 0.05911334, 0.06900725, 0.35230422, 0.09698894,
#          0.06947961, 0.30119535]], dtype=float32),
#  '015159640': array([[0.04331306, 0.06173155, 0.00647996, 0.08425975, 0.7773569 ,
#          0.01640233, 0.01045639]], dtype=float32),
#  '015256413': array([[0.3615062 , 0.06279891, 0.1712251 , 0.10409188, 0.05835635,
#          0.14457262, 0.09744889]], dtype=float32),
#  '015337240': array([[0.21319725, 0.03891977, 0.16770594, 0.24041395, 0.07644235,
#          0.06394131, 0.19937938]], dtype=float32),
#  '015407880': array([[0.05392565, 0.2528161 , 0.01120484, 0.52691716, 0.08369315,
#          0.030032  , 0.04141107]], dtype=float32),
#  '015441400': array([[0.09416479, 0.0941374 , 0.02533982, 0.1685534 , 0.5862318 ,
#          0.00851992, 0.02305283]], dtype=float32),
#  '015610480': array([[0.35412416, 0.09992471, 0.18475458, 0.14421722, 0.09834407,
#          0.05382823, 0.06480695]], dtype=float32),
#  '015653680': array([[0.00952675, 0.03099833, 0.03974662, 0.08011152, 0.19583671,
#          0.61236197, 0.03141813]], dtype=float32),
#  '020127800': array([[0.03994451, 0.07038711, 0.01679596, 0.08059994, 0.7610372 ,
#          0.01420534, 0.01703002]], dtype=float32),
#  '020913240': array([[0.6405991 , 0.01837928, 0.10097414, 0.08833453, 0.0104249 ,
#          0.04695147, 0.09433663]], dtype=float32),
#  '020950800': array([[0.16613822, 0.06427478, 0.01808735, 0.24515364, 0.3914404 ,
#          0.02946977, 0.0854359 ]], dtype=float32),
#  '021437680': array([[0.09055019, 0.16240223, 0.01494428, 0.18536042, 0.4438382 ,
#          0.0474056 , 0.05549912]], dtype=float32),
#  '021913080': array([[0.37207097, 0.08899813, 0.05654277, 0.2378451 , 0.05728971,
#          0.07492864, 0.11232468]], dtype=float32),
#  '023340360': array([[0.02524487, 0.06160857, 0.09068379, 0.09531696, 0.40670967,
#          0.0589461 , 0.2614901 ]], dtype=float32)}

# %%
127632141, 0.19602273404598236, 0.21022726595401764, 0.16761364042758942, 0.20738635957241058, 0.21875, 0.12215909361839294, 0.11363636702299118, 0.12215909361839294, 0.20454545319080353, 0.24147726595401764, 0.20454545319080353, 0.18465909361839294, 0.1818181872367859, 0.20454545319080353, 0.1818181872367859, 0.15340909361839294, 0.1931818127632141, 0.22159090638160706, 0.2130681872367859, 0.19886364042758942, 0.2642045319080353, 0.22159090638160706, 0.17897726595401764, 0.14772726595401764, 0.22159090638160706, 0.22727273404598236, 0.16761364042758942, 0.21875, 0.16477273404598236, 0.23579545319080353, 0.20454545319080353, 0.23579545319080353, 0.19886364042758942, 0.15340909361839294, 0.14204545319080353, 0.16761364042758942, 0.15625, 0.17329545319080353, 0.1875, 0.1931818127632141, 0.1931818127632141, 0.15909090638160706, 0.1931818127632141, 0.1931818127632141, 0.15340909361839294, 0.1818181872367859, 0.1931818127632141, 0.1818181872367859, 0.20170454680919647, 0.1818181872367859, 0.17329545319080353, 0.23011364042758942, 0.2130681872367859, 0.23295454680919647, 0.1818181872367859, 0.20170454680919647, 0.21875, 0.14772726595401764, 0.17897726595401764]

# %%
# !mkdir /content/gdrive/My Drive/TFM_MUSI/Audio/Results/results.csv
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My’: Operation not supported
# mkdir: cannot create directory ‘Drive/TFM_MUSI/Audio/Results/results.csv’: No such file or directory

# %%
#PARAMS:
params={}
params["num_prueba"]="Audio modelo 2"
params["description"]="Test con espectrogramas convertidos en imágenes arquitectura 2"
params["DROPOUT"]=DROPOUT
params["l2_regul"]=l2_regul
params["learning rate"]=lr
params["N_OUTPUT_LABELS"]=N_OUTPUT_LABELS
params["batch_size"]=batch_size
params["epochs"]=epochs
params["desired_audio_len"]=desired_audio_len
params["preemphasis"]=preemphasis
params["normalize"]=normalize
params["input_shape"]=input_shape
params["accuracy"]=history.history['accuracy']
params["val_accuracy"]=history.history['val_accuracy']

import csv
from csv import DictWriter

with open("/content/gdrive/My Drive/TFM_MUSI/Audio/results.csv", 'a') as f: 
  dictwriter_object = DictWriter(f, fieldnames=params.keys()) 
  dictwriter_object.writeheader()
  dictwriter_object.writerow(params) 
  f.close()

# %%
model=model2()
model.compile(optimizers.RMSprop(lr=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 62, 62, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 62, 62, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 31, 31, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 29, 29, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 29, 29, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 7)                 3591
# =================================================================
# Total params: 2,678,087
# Trainable params: 2,678,087
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
ES = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=35)
filepath="/content/gdrive/MyDrive/TFM_MUSI/combined_model2"

path=filepath+":{epoch:03d}-val_accuracy:{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callback_list=[ES,checkpoint]

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_TEST,
                    epochs=100,
                    callbacks=callback_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 24/24 [==============================] - 5s 95ms/step - loss: 1.9807 - accuracy: 0.1334 - val_loss: 1.9362 - val_accuracy: 0.1477
#
# Epoch 00001: val_accuracy improved from -inf to 0.14773, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 2/100
# 24/24 [==============================] - 1s 64ms/step - loss: 1.9289 - accuracy: 0.1486 - val_loss: 1.9475 - val_accuracy: 0.1591
#
# Epoch 00002: val_accuracy improved from 0.14773 to 0.15909, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 3/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.9541 - accuracy: 0.1619 - val_loss: 1.9466 - val_accuracy: 0.1676
#
# Epoch 00003: val_accuracy improved from 0.15909 to 0.16761, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 4/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.9133 - accuracy: 0.1683 - val_loss: 1.9335 - val_accuracy: 0.1932
#
# Epoch 00004: val_accuracy improved from 0.16761 to 0.19318, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 5/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.9230 - accuracy: 0.1796 - val_loss: 1.9302 - val_accuracy: 0.1875
#
# Epoch 00005: val_accuracy did not improve from 0.19318
# Epoch 6/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.9104 - accuracy: 0.1858 - val_loss: 1.9286 - val_accuracy: 0.1960
#
# Epoch 00006: val_accuracy improved from 0.19318 to 0.19602, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 7/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.9171 - accuracy: 0.1698 - val_loss: 1.9243 - val_accuracy: 0.1733
#
# Epoch 00007: val_accuracy did not improve from 0.19602
# Epoch 8/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.9037 - accuracy: 0.1961 - val_loss: 1.9213 - val_accuracy: 0.1989
#
# Epoch 00008: val_accuracy improved from 0.19602 to 0.19886, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 9/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8894 - accuracy: 0.2134 - val_loss: 1.9236 - val_accuracy: 0.1989
#
# Epoch 00009: val_accuracy did not improve from 0.19886
# Epoch 10/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8979 - accuracy: 0.2313 - val_loss: 1.9153 - val_accuracy: 0.2045
#
# Epoch 00010: val_accuracy improved from 0.19886 to 0.20455, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 11/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8748 - accuracy: 0.2416 - val_loss: 1.8962 - val_accuracy: 0.2273
#
# Epoch 00011: val_accuracy improved from 0.20455 to 0.22727, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 12/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.8693 - accuracy: 0.2292 - val_loss: 1.9096 - val_accuracy: 0.2330
#
# Epoch 00012: val_accuracy improved from 0.22727 to 0.23295, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 13/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8568 - accuracy: 0.2371 - val_loss: 1.9024 - val_accuracy: 0.2017
#
# Epoch 00013: val_accuracy did not improve from 0.23295
# Epoch 14/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8097 - accuracy: 0.2790 - val_loss: 1.9129 - val_accuracy: 0.2074
#
# Epoch 00014: val_accuracy did not improve from 0.23295
# Epoch 15/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.7893 - accuracy: 0.2948 - val_loss: 1.9387 - val_accuracy: 0.2216
#
# Epoch 00015: val_accuracy did not improve from 0.23295
# Epoch 16/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.7190 - accuracy: 0.3467 - val_loss: 1.8986 - val_accuracy: 0.2330
#
# Epoch 00016: val_accuracy did not improve from 0.23295
# Epoch 17/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.7266 - accuracy: 0.3221 - val_loss: 1.9611 - val_accuracy: 0.2500
#
# Epoch 00017: val_accuracy improved from 0.23295 to 0.25000, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 18/100
# 24/24 [==============================] - 2s 73ms/step - loss: 1.7529 - accuracy: 0.3117 - val_loss: 1.9155 - val_accuracy: 0.2273
#
# Epoch 00018: val_accuracy did not improve from 0.25000
# Epoch 19/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6906 - accuracy: 0.3442 - val_loss: 2.1163 - val_accuracy: 0.2216
#
# Epoch 00019: val_accuracy did not improve from 0.25000
# Epoch 20/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.6917 - accuracy: 0.3312 - val_loss: 1.9229 - val_accuracy: 0.2188
#
# Epoch 00020: val_accuracy did not improve from 0.25000
# Epoch 21/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.6369 - accuracy: 0.3838 - val_loss: 2.0846 - val_accuracy: 0.2472
#
# Epoch 00021: val_accuracy did not improve from 0.25000
# Epoch 22/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.6440 - accuracy: 0.3756 - val_loss: 1.9056 - val_accuracy: 0.2472
#
# Epoch 00022: val_accuracy did not improve from 0.25000
# Epoch 23/100
# 24/24 [==============================] - 1s 64ms/step - loss: 1.5922 - accuracy: 0.4012 - val_loss: 1.9803 - val_accuracy: 0.2500
#
# Epoch 00023: val_accuracy did not improve from 0.25000
# Epoch 24/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.4759 - accuracy: 0.4282 - val_loss: 2.0049 - val_accuracy: 0.2244
#
# Epoch 00024: val_accuracy did not improve from 0.25000
# Epoch 25/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5211 - accuracy: 0.4424 - val_loss: 2.0735 - val_accuracy: 0.2330
#
# Epoch 00025: val_accuracy did not improve from 0.25000
# Epoch 26/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.5261 - accuracy: 0.4187 - val_loss: 2.0951 - val_accuracy: 0.2273
#
# Epoch 00026: val_accuracy did not improve from 0.25000
# Epoch 27/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4591 - accuracy: 0.4750 - val_loss: 2.2158 - val_accuracy: 0.2443
#
# Epoch 00027: val_accuracy did not improve from 0.25000
# Epoch 28/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4555 - accuracy: 0.4683 - val_loss: 2.1452 - val_accuracy: 0.2415
#
# Epoch 00028: val_accuracy did not improve from 0.25000
# Epoch 29/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3317 - accuracy: 0.4991 - val_loss: 2.1962 - val_accuracy: 0.2301
#
# Epoch 00029: val_accuracy did not improve from 0.25000
# Epoch 30/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4444 - accuracy: 0.4792 - val_loss: 2.2575 - val_accuracy: 0.2443
#
# Epoch 00030: val_accuracy did not improve from 0.25000
# Epoch 31/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.2906 - accuracy: 0.5339 - val_loss: 2.2420 - val_accuracy: 0.2358
#
# Epoch 00031: val_accuracy did not improve from 0.25000
# Epoch 32/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.2629 - accuracy: 0.5279 - val_loss: 2.4228 - val_accuracy: 0.2017
#
# Epoch 00032: val_accuracy did not improve from 0.25000
# Epoch 33/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.2074 - accuracy: 0.5572 - val_loss: 2.3718 - val_accuracy: 0.2358
#
# Epoch 00033: val_accuracy did not improve from 0.25000
# Epoch 34/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.1690 - accuracy: 0.5697 - val_loss: 2.4421 - val_accuracy: 0.2188
#
# Epoch 00034: val_accuracy did not improve from 0.25000
# Epoch 35/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.1293 - accuracy: 0.6053 - val_loss: 2.6193 - val_accuracy: 0.2358
#
# Epoch 00035: val_accuracy did not improve from 0.25000
# Epoch 36/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.0568 - accuracy: 0.6261 - val_loss: 2.7891 - val_accuracy: 0.2585
#
# Epoch 00036: val_accuracy improved from 0.25000 to 0.25852, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 37/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0651 - accuracy: 0.6248 - val_loss: 2.4770 - val_accuracy: 0.2500
#
# Epoch 00037: val_accuracy did not improve from 0.25852
# Epoch 38/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.9093 - accuracy: 0.6661 - val_loss: 2.7911 - val_accuracy: 0.2472
#
# Epoch 00038: val_accuracy did not improve from 0.25852
# Epoch 39/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.9079 - accuracy: 0.6621 - val_loss: 2.8485 - val_accuracy: 0.2301
#
# Epoch 00039: val_accuracy did not improve from 0.25852
# Epoch 40/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.9664 - accuracy: 0.6775 - val_loss: 2.9986 - val_accuracy: 0.2443
#
# Epoch 00040: val_accuracy did not improve from 0.25852
# Epoch 41/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.8741 - accuracy: 0.7037 - val_loss: 2.9300 - val_accuracy: 0.2415
#
# Epoch 00041: val_accuracy did not improve from 0.25852
# Epoch 42/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.7538 - accuracy: 0.7164 - val_loss: 2.9349 - val_accuracy: 0.2244
#
# Epoch 00042: val_accuracy did not improve from 0.25852
# Epoch 43/100
# 24/24 [==============================] - 2s 74ms/step - loss: 0.7971 - accuracy: 0.7075 - val_loss: 3.2374 - val_accuracy: 0.2301
#
# Epoch 00043: val_accuracy did not improve from 0.25852
# Epoch 44/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.7118 - accuracy: 0.7415 - val_loss: 3.1516 - val_accuracy: 0.2273
#
# Epoch 00044: val_accuracy did not improve from 0.25852
# Epoch 45/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.7112 - accuracy: 0.7732 - val_loss: 3.1527 - val_accuracy: 0.2102
#
# Epoch 00045: val_accuracy did not improve from 0.25852
# Epoch 46/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.6591 - accuracy: 0.7977 - val_loss: 3.3203 - val_accuracy: 0.2188
#
# Epoch 00046: val_accuracy did not improve from 0.25852
# Epoch 47/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5892 - accuracy: 0.7733 - val_loss: 3.5950 - val_accuracy: 0.2188
#
# Epoch 00047: val_accuracy did not improve from 0.25852
# Epoch 48/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5506 - accuracy: 0.8139 - val_loss: 3.4544 - val_accuracy: 0.2386
#
# Epoch 00048: val_accuracy did not improve from 0.25852
# Epoch 49/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5616 - accuracy: 0.8054 - val_loss: 3.6395 - val_accuracy: 0.2472
#
# Epoch 00049: val_accuracy did not improve from 0.25852
# Epoch 50/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5320 - accuracy: 0.8252 - val_loss: 3.8672 - val_accuracy: 0.2528
#
# Epoch 00050: val_accuracy did not improve from 0.25852
# Epoch 51/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.4471 - accuracy: 0.8427 - val_loss: 4.1297 - val_accuracy: 0.2301
#
# Epoch 00051: val_accuracy did not improve from 0.25852
# Epoch 52/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.4881 - accuracy: 0.8494 - val_loss: 4.0072 - val_accuracy: 0.2528
#
# Epoch 00052: val_accuracy did not improve from 0.25852
# Epoch 53/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5210 - accuracy: 0.8292 - val_loss: 4.1676 - val_accuracy: 0.2614
#
# Epoch 00053: val_accuracy improved from 0.25852 to 0.26136, saving model to /content/gdrive/MyDrive/TFM_MUSI/combined_model2
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/TFM_MUSI/combined_model2/assets
# Epoch 54/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.4950 - accuracy: 0.8198 - val_loss: 4.8194 - val_accuracy: 0.2500
#
# Epoch 00054: val_accuracy did not improve from 0.26136
# Epoch 55/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.4622 - accuracy: 0.8303 - val_loss: 4.8834 - val_accuracy: 0.2330
#
# Epoch 00055: val_accuracy did not improve from 0.26136
# Epoch 56/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.4036 - accuracy: 0.8543 - val_loss: 4.1367 - val_accuracy: 0.2159
#
# Epoch 00056: val_accuracy did not improve from 0.26136
# Epoch 57/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.3416 - accuracy: 0.8759 - val_loss: 5.0323 - val_accuracy: 0.2415
#
# Epoch 00057: val_accuracy did not improve from 0.26136
# Epoch 58/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.3512 - accuracy: 0.8891 - val_loss: 4.7165 - val_accuracy: 0.2244
#
# Epoch 00058: val_accuracy did not improve from 0.26136
# Epoch 59/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.3855 - accuracy: 0.8494 - val_loss: 5.4047 - val_accuracy: 0.2500
#
# Epoch 00059: val_accuracy did not improve from 0.26136
# Epoch 60/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.3828 - accuracy: 0.8640 - val_loss: 4.7865 - val_accuracy: 0.2358
#
# Epoch 00060: val_accuracy did not improve from 0.26136
# Epoch 61/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.4016 - accuracy: 0.8469 - val_loss: 4.9622 - val_accuracy: 0.2386
#
# Epoch 00061: val_accuracy did not improve from 0.26136
# Epoch 62/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.3198 - accuracy: 0.8903 - val_loss: 4.6208 - val_accuracy: 0.2273
#
# Epoch 00062: val_accuracy did not improve from 0.26136
# Epoch 63/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.2033 - accuracy: 0.9367 - val_loss: 5.1495 - val_accuracy: 0.2330
#
# Epoch 00063: val_accuracy did not improve from 0.26136
# Epoch 64/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2698 - accuracy: 0.9114 - val_loss: 5.2539 - val_accuracy: 0.2386
#
# Epoch 00064: val_accuracy did not improve from 0.26136
# Epoch 65/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.2270 - accuracy: 0.9189 - val_loss: 4.8348 - val_accuracy: 0.2443
#
# Epoch 00065: val_accuracy did not improve from 0.26136
# Epoch 66/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.2932 - accuracy: 0.9002 - val_loss: 5.4600 - val_accuracy: 0.2102
#
# Epoch 00066: val_accuracy did not improve from 0.26136
# Epoch 67/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.3052 - accuracy: 0.8929 - val_loss: 5.7116 - val_accuracy: 0.2216
#
# Epoch 00067: val_accuracy did not improve from 0.26136
# Epoch 68/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2489 - accuracy: 0.9198 - val_loss: 5.1011 - val_accuracy: 0.2244
#
# Epoch 00068: val_accuracy did not improve from 0.26136
# Epoch 69/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.2694 - accuracy: 0.9071 - val_loss: 5.1125 - val_accuracy: 0.2188
#
# Epoch 00069: val_accuracy did not improve from 0.26136
# Epoch 70/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2701 - accuracy: 0.9092 - val_loss: 4.8822 - val_accuracy: 0.2216
#
# Epoch 00070: val_accuracy did not improve from 0.26136
# Epoch 71/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.2141 - accuracy: 0.9424 - val_loss: 5.9477 - val_accuracy: 0.2358
#
# Epoch 00071: val_accuracy did not improve from 0.26136
# Epoch 72/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2323 - accuracy: 0.9265 - val_loss: 6.1674 - val_accuracy: 0.2216
#
# Epoch 00072: val_accuracy did not improve from 0.26136
# Epoch 73/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2808 - accuracy: 0.9362 - val_loss: 4.9683 - val_accuracy: 0.2386
#
# Epoch 00073: val_accuracy did not improve from 0.26136
# Epoch 74/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.1605 - accuracy: 0.9426 - val_loss: 5.2138 - val_accuracy: 0.2045
#
# Epoch 00074: val_accuracy did not improve from 0.26136
# Epoch 75/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2569 - accuracy: 0.9095 - val_loss: 6.9002 - val_accuracy: 0.2330
#
# Epoch 00075: val_accuracy did not improve from 0.26136
# Epoch 76/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2362 - accuracy: 0.9194 - val_loss: 5.9592 - val_accuracy: 0.2244
#
# Epoch 00076: val_accuracy did not improve from 0.26136
# Epoch 77/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1453 - accuracy: 0.9535 - val_loss: 5.8788 - val_accuracy: 0.2301
#
# Epoch 00077: val_accuracy did not improve from 0.26136
# Epoch 78/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.1840 - accuracy: 0.9444 - val_loss: 5.2451 - val_accuracy: 0.2188
#
# Epoch 00078: val_accuracy did not improve from 0.26136
# Epoch 79/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2234 - accuracy: 0.9174 - val_loss: 5.6728 - val_accuracy: 0.2045
#
# Epoch 00079: val_accuracy did not improve from 0.26136
# Epoch 80/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2172 - accuracy: 0.9286 - val_loss: 6.1527 - val_accuracy: 0.2386
#
# Epoch 00080: val_accuracy did not improve from 0.26136
# Epoch 81/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.1509 - accuracy: 0.9488 - val_loss: 6.2793 - val_accuracy: 0.2159
#
# Epoch 00081: val_accuracy did not improve from 0.26136
# Epoch 82/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.2043 - accuracy: 0.9255 - val_loss: 5.8606 - val_accuracy: 0.2330
#
# Epoch 00082: val_accuracy did not improve from 0.26136
# Epoch 83/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.1333 - accuracy: 0.9579 - val_loss: 6.5164 - val_accuracy: 0.2472
#
# Epoch 00083: val_accuracy did not improve from 0.26136
# Epoch 84/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.1559 - accuracy: 0.9512 - val_loss: 9.3048 - val_accuracy: 0.2614
#
# Epoch 00084: val_accuracy did not improve from 0.26136
# Epoch 85/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2775 - accuracy: 0.9233 - val_loss: 6.1995 - val_accuracy: 0.2330
#
# Epoch 00085: val_accuracy did not improve from 0.26136
# Epoch 86/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1223 - accuracy: 0.9529 - val_loss: 6.3316 - val_accuracy: 0.2301
#
# Epoch 00086: val_accuracy did not improve from 0.26136
# Epoch 87/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.1031 - accuracy: 0.9666 - val_loss: 6.1202 - val_accuracy: 0.2216
#
# Epoch 00087: val_accuracy did not improve from 0.26136
# Epoch 88/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.1489 - accuracy: 0.9619 - val_loss: 6.1956 - val_accuracy: 0.2216
#
# Epoch 00088: val_accuracy did not improve from 0.26136
# Epoch 89/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0939 - accuracy: 0.9748 - val_loss: 6.6573 - val_accuracy: 0.2159
#
# Epoch 00089: val_accuracy did not improve from 0.26136
# Epoch 90/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1312 - accuracy: 0.9696 - val_loss: 6.1922 - val_accuracy: 0.2188
#
# Epoch 00090: val_accuracy did not improve from 0.26136
# Epoch 91/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1126 - accuracy: 0.9738 - val_loss: 6.6492 - val_accuracy: 0.2074
#
# Epoch 00091: val_accuracy did not improve from 0.26136
# Epoch 92/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.1613 - accuracy: 0.9360 - val_loss: 6.8088 - val_accuracy: 0.2244
#
# Epoch 00092: val_accuracy did not improve from 0.26136
# Epoch 93/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1083 - accuracy: 0.9672 - val_loss: 6.5769 - val_accuracy: 0.2131
#
# Epoch 00093: val_accuracy did not improve from 0.26136
# Epoch 94/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1173 - accuracy: 0.9674 - val_loss: 5.9126 - val_accuracy: 0.2074
#
# Epoch 00094: val_accuracy did not improve from 0.26136
# Epoch 95/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.1513 - accuracy: 0.9500 - val_loss: 5.7867 - val_accuracy: 0.2273
#
# Epoch 00095: val_accuracy did not improve from 0.26136
# Epoch 96/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0902 - accuracy: 0.9675 - val_loss: 6.1605 - val_accuracy: 0.2273
#
# Epoch 00096: val_accuracy did not improve from 0.26136
# Epoch 97/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1118 - accuracy: 0.9617 - val_loss: 6.2336 - val_accuracy: 0.2216
#
# Epoch 00097: val_accuracy did not improve from 0.26136
# Epoch 98/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1246 - accuracy: 0.9608 - val_loss: 6.3017 - val_accuracy: 0.2188
#
# Epoch 00098: val_accuracy did not improve from 0.26136
# Epoch 99/100
# 24/24 [==============================] - 2s 74ms/step - loss: 0.1070 - accuracy: 0.9566 - val_loss: 7.3529 - val_accuracy: 0.2102
#
# Epoch 00099: val_accuracy did not improve from 0.26136
# Epoch 100/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.1130 - accuracy: 0.9638 - val_loss: 7.1273 - val_accuracy: 0.2415
#
# Epoch 00100: val_accuracy did not improve from 0.26136

# %%
plot_model(history,"model2 imatges specs EMOTIW_audio_to_image arquitectura Urbansound")
plt.figure()
# plt.plot(history.history["validation_accuracy"])

# %%
#Prova 2: No pre-emphasis

img_width, img_height=64,64
lr=1e-4
batch_size=32

train_generator,test_generator=create_sets(train_dir,test_dir,batch_size)
model_VGG_audio=create_model(8,dropout=0.5)
model_VGG_audio.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.SGD(lr=lr, momentum=0.9),
                metrics=['accuracy','categorical_accuracy'])

# path=filepath+"VGGTEST"+":{epoch:03d}-val_accuracy:{val_accuracy:.3f}.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

E_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                              min_delta=0,
                                              patience=20,
                                              verbose=1,
                                              mode="auto",
                                              restore_best_weights=True)
callback_list = [E_stopping]

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

history=model_VGG_audio.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_TEST,
                    epochs=60,
                    callbacks=callback_list)
path=""
plot_model(history,"vgg16 model last conv block fine tuned audio converted to spectrogram images")
title="vgg16 last conv block fine-tuned audio spectrogram images"
plt.figure()
plot_conf_matrix(test_generator,model_VGG_audio,path,title,standard_format=True,percentages=True,save_plot=True)
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.
# VGG_summary:
# [<keras.engine.input_layer.InputLayer object at 0x7f479bc6c510>, <keras.layers.convolutional.Conv2D object at 0x7f479c313610>, <keras.layers.convolutional.Conv2D object at 0x7f479bc33250>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c313690>, <keras.layers.convolutional.Conv2D object at 0x7f479c2ae350>, <keras.layers.convolutional.Conv2D object at 0x7f479bc0a410>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c2ae6d0>, <keras.layers.convolutional.Conv2D object at 0x7f479c2cf790>, <keras.layers.convolutional.Conv2D object at 0x7f479c2cf750>, <keras.layers.convolutional.Conv2D object at 0x7f472834d890>, <keras.layers.pooling.MaxPooling2D object at 0x7f4728345c10>, <keras.layers.convolutional.Conv2D object at 0x7f47283538d0>, <keras.layers.convolutional.Conv2D object at 0x7f472835b550>, <keras.layers.convolutional.Conv2D object at 0x7f472835b5d0>, <keras.layers.pooling.MaxPooling2D object at 0x7f4728360d10>, <keras.layers.convolutional.Conv2D object at 0x7f47283696d0>, <keras.layers.convolutional.Conv2D object at 0x7f479be4bd50>, <keras.layers.convolutional.Conv2D object at 0x7f47283652d0>, <keras.layers.pooling.MaxPooling2D object at 0x7f4728369250>, <keras.layers.core.Flatten object at 0x7f4728383190>, <keras.layers.core.Dense object at 0x7f479bea2090>, <keras.layers.core.Dropout object at 0x7f479c29c150>, <keras.layers.core.Dense object at 0x7f479c227150>]
# freezing layer:  input_7
# freezing layer:  block1_conv1
# freezing layer:  block1_conv2
# freezing layer:  block1_pool
# freezing layer:  block2_conv1
# freezing layer:  block2_conv2
# freezing layer:  block2_pool
# freezing layer:  block3_conv1
# freezing layer:  block3_conv2
# freezing layer:  block3_conv3
# freezing layer:  block3_pool
# freezing layer:  block4_conv1
# freezing layer:  block4_conv2
# freezing layer:  block4_conv3
# freezing layer:  block4_pool
# new_model summary!
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 7175
# =================================================================
# Total params: 16,820,039
# Trainable params: 9,184,775
# Non-trainable params: 7,635,264
# _________________________________________________________________
# Epoch 1/60
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 24/24 [==============================] - 4s 121ms/step - loss: 2.1797 - accuracy: 0.1795 - categorical_accuracy: 0.1795 - val_loss: 1.8905 - val_accuracy: 0.2131 - val_categorical_accuracy: 0.2131
# Epoch 2/60
# 24/24 [==============================] - 2s 94ms/step - loss: 2.0391 - accuracy: 0.1862 - categorical_accuracy: 0.1862 - val_loss: 1.8914 - val_accuracy: 0.2386 - val_categorical_accuracy: 0.2386
# Epoch 3/60
# 24/24 [==============================] - 2s 92ms/step - loss: 2.0155 - accuracy: 0.1903 - categorical_accuracy: 0.1903 - val_loss: 1.8759 - val_accuracy: 0.2159 - val_categorical_accuracy: 0.2159
# Epoch 4/60
# 24/24 [==============================] - 2s 96ms/step - loss: 1.9928 - accuracy: 0.1862 - categorical_accuracy: 0.1862 - val_loss: 1.8749 - val_accuracy: 0.2528 - val_categorical_accuracy: 0.2528
# Epoch 5/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.9506 - accuracy: 0.2078 - categorical_accuracy: 0.2078 - val_loss: 1.8712 - val_accuracy: 0.2330 - val_categorical_accuracy: 0.2330
# Epoch 6/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.9300 - accuracy: 0.2294 - categorical_accuracy: 0.2294 - val_loss: 1.8509 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
# Epoch 7/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.9174 - accuracy: 0.2024 - categorical_accuracy: 0.2024 - val_loss: 1.8393 - val_accuracy: 0.2727 - val_categorical_accuracy: 0.2727
# Epoch 8/60
# 24/24 [==============================] - 2s 91ms/step - loss: 1.9047 - accuracy: 0.2483 - categorical_accuracy: 0.2483 - val_loss: 1.8315 - val_accuracy: 0.2557 - val_categorical_accuracy: 0.2557
# Epoch 9/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.8740 - accuracy: 0.2537 - categorical_accuracy: 0.2537 - val_loss: 1.8234 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
# Epoch 10/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.8637 - accuracy: 0.2605 - categorical_accuracy: 0.2605 - val_loss: 1.8202 - val_accuracy: 0.2784 - val_categorical_accuracy: 0.2784
# Epoch 11/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.8390 - accuracy: 0.2552 - categorical_accuracy: 0.2552 - val_loss: 1.8123 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
# Epoch 12/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.8122 - accuracy: 0.2794 - categorical_accuracy: 0.2794 - val_loss: 1.8148 - val_accuracy: 0.2642 - val_categorical_accuracy: 0.2642
# Epoch 13/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.8174 - accuracy: 0.2901 - categorical_accuracy: 0.2901 - val_loss: 1.8127 - val_accuracy: 0.2955 - val_categorical_accuracy: 0.2955
# Epoch 14/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.8022 - accuracy: 0.2888 - categorical_accuracy: 0.2888 - val_loss: 1.8092 - val_accuracy: 0.2869 - val_categorical_accuracy: 0.2869
# Epoch 15/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.7913 - accuracy: 0.2915 - categorical_accuracy: 0.2915 - val_loss: 1.8105 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 16/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.7690 - accuracy: 0.3009 - categorical_accuracy: 0.3009 - val_loss: 1.8001 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 17/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.7714 - accuracy: 0.2982 - categorical_accuracy: 0.2982 - val_loss: 1.7956 - val_accuracy: 0.3097 - val_categorical_accuracy: 0.3097
# Epoch 18/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.7374 - accuracy: 0.2928 - categorical_accuracy: 0.2928 - val_loss: 1.7925 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
# Epoch 19/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.7366 - accuracy: 0.3185 - categorical_accuracy: 0.3185 - val_loss: 1.7907 - val_accuracy: 0.2955 - val_categorical_accuracy: 0.2955
# Epoch 20/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.7488 - accuracy: 0.3144 - categorical_accuracy: 0.3144 - val_loss: 1.7964 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 21/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.7033 - accuracy: 0.3495 - categorical_accuracy: 0.3495 - val_loss: 1.7902 - val_accuracy: 0.2898 - val_categorical_accuracy: 0.2898
# Epoch 22/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.7262 - accuracy: 0.3536 - categorical_accuracy: 0.3536 - val_loss: 1.7873 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
# Epoch 23/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.7204 - accuracy: 0.3306 - categorical_accuracy: 0.3306 - val_loss: 1.7932 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 24/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.6919 - accuracy: 0.3455 - categorical_accuracy: 0.3455 - val_loss: 1.8033 - val_accuracy: 0.2756 - val_categorical_accuracy: 0.2756
# Epoch 25/60
# 24/24 [==============================] - 2s 96ms/step - loss: 1.6851 - accuracy: 0.3590 - categorical_accuracy: 0.3590 - val_loss: 1.7909 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 26/60
# 24/24 [==============================] - 2s 95ms/step - loss: 1.6775 - accuracy: 0.3360 - categorical_accuracy: 0.3360 - val_loss: 1.7912 - val_accuracy: 0.3040 - val_categorical_accuracy: 0.3040
# Epoch 27/60
# 24/24 [==============================] - 2s 95ms/step - loss: 1.6475 - accuracy: 0.3958 - categorical_accuracy: 0.3958 - val_loss: 1.7896 - val_accuracy: 0.2983 - val_categorical_accuracy: 0.2983
# Epoch 28/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.6692 - accuracy: 0.3698 - categorical_accuracy: 0.3698 - val_loss: 1.8068 - val_accuracy: 0.2699 - val_categorical_accuracy: 0.2699
# Epoch 29/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.6441 - accuracy: 0.3765 - categorical_accuracy: 0.3765 - val_loss: 1.7902 - val_accuracy: 0.2955 - val_categorical_accuracy: 0.2955
# Epoch 30/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.6535 - accuracy: 0.3927 - categorical_accuracy: 0.3927 - val_loss: 1.8027 - val_accuracy: 0.2784 - val_categorical_accuracy: 0.2784
# Epoch 31/60
# 24/24 [==============================] - 2s 97ms/step - loss: 1.6327 - accuracy: 0.3941 - categorical_accuracy: 0.3941 - val_loss: 1.7899 - val_accuracy: 0.3068 - val_categorical_accuracy: 0.3068
# Epoch 32/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.6276 - accuracy: 0.3833 - categorical_accuracy: 0.3833 - val_loss: 1.7920 - val_accuracy: 0.3068 - val_categorical_accuracy: 0.3068
# Epoch 33/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.6295 - accuracy: 0.3833 - categorical_accuracy: 0.3833 - val_loss: 1.7876 - val_accuracy: 0.2926 - val_categorical_accuracy: 0.2926
# Epoch 34/60
# 24/24 [==============================] - 2s 94ms/step - loss: 1.6010 - accuracy: 0.3880 - categorical_accuracy: 0.3880 - val_loss: 1.8026 - val_accuracy: 0.2841 - val_categorical_accuracy: 0.2841
# Epoch 35/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.5985 - accuracy: 0.4089 - categorical_accuracy: 0.4089 - val_loss: 1.8029 - val_accuracy: 0.2812 - val_categorical_accuracy: 0.2812
# Epoch 36/60
# 24/24 [==============================] - 2s 93ms/step - loss: 1.5950 - accuracy: 0.4049 - categorical_accuracy: 0.4049 - val_loss: 1.8064 - val_accuracy: 0.2784 - val_categorical_accuracy: 0.2784
# Epoch 37/60
# 24/24 [==============================] - 2s 92ms/step - loss: 1.5717 - accuracy: 0.4157 - categorical_accuracy: 0.4157 - val_loss: 1.7989 - val_accuracy: 0.3011 - val_categorical_accuracy: 0.3011
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 381
# [[35  0  0 21  7  1  0]
#  [10  0  0 16 11  3  0]
#  [ 8  0  4 22  8  4  0]
#  [12  0  1 29 17  4  0]
#  [10  0  0 15 32  4  0]
#  [ 9  0  2 23 18  9  0]
#  [ 8  0  2 19 12  5  0]]
#
# accuracy:  0.28608923884514437
# f1 score: [0.44871795 0.         0.14545455 0.27884615 0.38554217 0.1978022
#  0.        ]
# f1 score weighted: 0.232441395948179
# ---------------------------------------------------------
# vgg16 last conv block fine-tuned audio spectrogram images

# %%
#PARAMS:
# lr=0.0005
# epochs=100
# preemphasis=False
# normalize=False
# desired_audio_len="no standarized"

# params={}
# params["num_prueba"]="Audio prueba modelo2"
# params["description"]="Test con espectrogramas convertidos en imágenes arquitectura de USound"
# params["DROPOUT"]=DROPOUT
# params["l2_regul"]=l2_regul
# params["learning rate"]=lr
# params["N_OUTPUT_LABELS"]=N_OUTPUT_LABELS
# params["batch_size"]=batch_size
# params["epochs"]=epochs
# params["desired_audio_len"]=desired_audio_len
# params["preemphasis"]=preemphasis
# params["normalize"]=normalize
# params["input_shape"]=input_shape
# params["accuracy"]=history.history['accuracy']
# params["val_accuracy"]=history.history['val_accuracy']

# import csv
# from csv import DictWriter

# with open("/content/gdrive/My Drive/TFM_MUSI/Audio/results.csv", 'a') as f: 
#   dictwriter_object = DictWriter(f, fieldnames=params.keys()) 
#   dictwriter_object.writeheader()
#   dictwriter_object.writerow(params) 
#   f.close()

# %%
#TEST: prova arquitectura 2 amb preemphasis

# %%
for audio_file in urls_afew_test:
  file_id=os.path.split(audio_file)[1].split(".")[0]
  label=dict_xy_afew[file_id]
  saving_file="spec_images/test/"+label+"/"+file_id
  create_spectrogram_test(audio_file,saving_file,preemphasis=True)

for audio_file in urls_afew_train:
  file_id=os.path.split(audio_file)[1].split(".")[0]
  label=dict_xy_afew[file_id]
  saving_file="spec_images/train/"+label+"/"+file_id
  create_spectrogram_test(audio_file,saving_file,preemphasis=True)

# %%
train_dir= '/content/spec_images/train'
test_dir= '/content/spec_images/test'
train_generator,test_generator=create_sets(train_dir,test_dir)
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.

# %%
model=model2()
model.compile(optimizers.RMSprop(lr=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
# model.summary()
callback_list = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=35)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
history=model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_TEST,
                    epochs=100,
                    callbacks=callback_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 24/24 [==============================] - 4s 100ms/step - loss: 1.9622 - accuracy: 0.1956 - val_loss: 1.9400 - val_accuracy: 0.1591
# Epoch 2/100
# 24/24 [==============================] - 2s 80ms/step - loss: 1.9484 - accuracy: 0.1867 - val_loss: 1.9372 - val_accuracy: 0.1562
# Epoch 3/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.9305 - accuracy: 0.1450 - val_loss: 1.9360 - val_accuracy: 0.1648
# Epoch 4/100
# 24/24 [==============================] - 2s 73ms/step - loss: 1.9246 - accuracy: 0.1838 - val_loss: 1.9316 - val_accuracy: 0.1648
# Epoch 5/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.9335 - accuracy: 0.1982 - val_loss: 1.9321 - val_accuracy: 0.1591
# Epoch 6/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.9005 - accuracy: 0.1669 - val_loss: 1.9317 - val_accuracy: 0.1676
# Epoch 7/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.9269 - accuracy: 0.1596 - val_loss: 1.9313 - val_accuracy: 0.1847
# Epoch 8/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.9118 - accuracy: 0.1853 - val_loss: 1.9327 - val_accuracy: 0.1591
# Epoch 9/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.9201 - accuracy: 0.1777 - val_loss: 1.9473 - val_accuracy: 0.1676
# Epoch 10/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.9187 - accuracy: 0.2212 - val_loss: 1.9305 - val_accuracy: 0.1648
# Epoch 11/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.9159 - accuracy: 0.1835 - val_loss: 1.9430 - val_accuracy: 0.1790
# Epoch 12/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.9167 - accuracy: 0.1974 - val_loss: 1.9267 - val_accuracy: 0.1761
# Epoch 13/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.8845 - accuracy: 0.1813 - val_loss: 1.9271 - val_accuracy: 0.1932
# Epoch 14/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.8833 - accuracy: 0.2349 - val_loss: 1.9284 - val_accuracy: 0.2045
# Epoch 15/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.8716 - accuracy: 0.2191 - val_loss: 1.9524 - val_accuracy: 0.1534
# Epoch 16/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.8667 - accuracy: 0.2417 - val_loss: 1.9262 - val_accuracy: 0.1733
# Epoch 17/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.8206 - accuracy: 0.2727 - val_loss: 1.9183 - val_accuracy: 0.1932
# Epoch 18/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.7975 - accuracy: 0.2844 - val_loss: 1.8938 - val_accuracy: 0.2273
# Epoch 19/100
# 24/24 [==============================] - 2s 72ms/step - loss: 1.7633 - accuracy: 0.3112 - val_loss: 1.9820 - val_accuracy: 0.2273
# Epoch 20/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.7639 - accuracy: 0.2966 - val_loss: 1.9177 - val_accuracy: 0.1960
# Epoch 21/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.7513 - accuracy: 0.3339 - val_loss: 1.9529 - val_accuracy: 0.2244
# Epoch 22/100
# 24/24 [==============================] - 2s 73ms/step - loss: 1.6965 - accuracy: 0.3387 - val_loss: 2.0034 - val_accuracy: 0.2216
# Epoch 23/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.6730 - accuracy: 0.3173 - val_loss: 1.9900 - val_accuracy: 0.2102
# Epoch 24/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.6692 - accuracy: 0.3580 - val_loss: 2.0072 - val_accuracy: 0.2244
# Epoch 25/100
# 24/24 [==============================] - 2s 69ms/step - loss: 1.5709 - accuracy: 0.4127 - val_loss: 2.3162 - val_accuracy: 0.2188
# Epoch 26/100
# 24/24 [==============================] - 2s 75ms/step - loss: 1.5920 - accuracy: 0.4281 - val_loss: 2.0107 - val_accuracy: 0.2131
# Epoch 27/100
# 24/24 [==============================] - 2s 70ms/step - loss: 1.5251 - accuracy: 0.4270 - val_loss: 1.9789 - val_accuracy: 0.2216
# Epoch 28/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.5026 - accuracy: 0.4373 - val_loss: 2.2055 - val_accuracy: 0.2017
# Epoch 29/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.4720 - accuracy: 0.4667 - val_loss: 2.2565 - val_accuracy: 0.2102
# Epoch 30/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.4434 - accuracy: 0.4553 - val_loss: 2.1436 - val_accuracy: 0.2301
# Epoch 31/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1.3736 - accuracy: 0.4861 - val_loss: 2.2883 - val_accuracy: 0.2330
# Epoch 32/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3392 - accuracy: 0.4881 - val_loss: 2.3318 - val_accuracy: 0.2415
# Epoch 33/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.3491 - accuracy: 0.5134 - val_loss: 2.3834 - val_accuracy: 0.2273
# Epoch 34/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.2169 - accuracy: 0.5490 - val_loss: 2.2546 - val_accuracy: 0.2330
# Epoch 35/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1748 - accuracy: 0.5903 - val_loss: 2.2795 - val_accuracy: 0.2188
# Epoch 36/100
# 24/24 [==============================] - 2s 65ms/step - loss: 1.1858 - accuracy: 0.5781 - val_loss: 2.6022 - val_accuracy: 0.2188
# Epoch 37/100
# 24/24 [==============================] - 2s 67ms/step - loss: 1
100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.3038 - accuracy: 0.8769 - val_loss: 5.3643 - val_accuracy: 0.1960
# Epoch 67/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.2615 - accuracy: 0.9091 - val_loss: 6.0261 - val_accuracy: 0.2159
# Epoch 68/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.3692 - accuracy: 0.8819 - val_loss: 5.5414 - val_accuracy: 0.2017
# Epoch 69/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.2933 - accuracy: 0.8898 - val_loss: 5.8102 - val_accuracy: 0.1903
# Epoch 70/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.2357 - accuracy: 0.9278 - val_loss: 6.1087 - val_accuracy: 0.2045
# Epoch 71/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.2371 - accuracy: 0.9230 - val_loss: 5.4405 - val_accuracy: 0.2102
# Epoch 72/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.2033 - accuracy: 0.9373 - val_loss: 6.3579 - val_accuracy: 0.2159
# Epoch 73/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.2396 - accuracy: 0.9188 - val_loss: 6.1854 - val_accuracy: 0.2045
# Epoch 74/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.2086 - accuracy: 0.9131 - val_loss: 5.8316 - val_accuracy: 0.1989
# Epoch 75/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.2230 - accuracy: 0.9291 - val_loss: 5.4014 - val_accuracy: 0.1875
# Epoch 76/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.2451 - accuracy: 0.9122 - val_loss: 6.8974 - val_accuracy: 0.1875
# Epoch 77/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.3742 - accuracy: 0.8818 - val_loss: 6.1351 - val_accuracy: 0.2045
# Epoch 78/100
# 24/24 [==============================] - 1s 63ms/step - loss: 0.1508 - accuracy: 0.9480 - val_loss: 6.0100 - val_accuracy: 0.1903
# Epoch 79/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1974 - accuracy: 0.9388 - val_loss: 5.7845 - val_accuracy: 0.2045
# Epoch 80/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1879 - accuracy: 0.9368 - val_loss: 5.9492 - val_accuracy: 0.1989
# Epoch 81/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1811 - accuracy: 0.9397 - val_loss: 6.4453 - val_accuracy: 0.1989
# Epoch 82/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1245 - accuracy: 0.9521 - val_loss: 6.6649 - val_accuracy: 0.1989
# Epoch 83/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1975 - accuracy: 0.9539 - val_loss: 5.5089 - val_accuracy: 0.2074
# Epoch 84/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1780 - accuracy: 0.9467 - val_loss: 6.0122 - val_accuracy: 0.2102
# Epoch 85/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1165 - accuracy: 0.9640 - val_loss: 6.9443 - val_accuracy: 0.1903
# Epoch 86/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1506 - accuracy: 0.9541 - val_loss: 6.4269 - val_accuracy: 0.1989
# Epoch 87/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.1534 - accuracy: 0.9537 - val_loss: 6.1189 - val_accuracy: 0.1932
# Epoch 88/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1780 - accuracy: 0.9490 - val_loss: 6.5001 - val_accuracy: 0.2074
# Epoch 89/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1263 - accuracy: 0.9658 - val_loss: 6.5636 - val_accuracy: 0.2102
# Epoch 90/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1225 - accuracy: 0.9647 - val_loss: 7.2402 - val_accuracy: 0.1932
# Epoch 91/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1581 - accuracy: 0.9408 - val_loss: 7.3055 - val_accuracy: 0.1932
# Epoch 92/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1292 - accuracy: 0.9548 - val_loss: 7.1935 - val_accuracy: 0.2017
# Epoch 93/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1685 - accuracy: 0.9293 - val_loss: 5.8648 - val_accuracy: 0.1705
# Epoch 94/100
# 24/24 [==============================] - 1s 64ms/step - loss: 0.1102 - accuracy: 0.9701 - val_loss: 6.0816 - val_accuracy: 0.2045
# Epoch 95/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0909 - accuracy: 0.9647 - val_loss: 5.7451 - val_accuracy: 0.2188
# Epoch 96/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0715 - accuracy: 0.9715 - val_loss: 6.8199 - val_accuracy: 0.2273
# Epoch 97/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.1392 - accuracy: 0.9525 - val_loss: 6.6015 - val_accuracy: 0.1847
# Epoch 98/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0988 - accuracy: 0.9698 - val_loss: 6.7873 - val_accuracy: 0.2017
# Epoch 99/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1210 - accuracy: 0.9650 - val_loss: 6.7419 - val_accuracy: 0.1875
# Epoch 100/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1137 - accuracy: 0.9559 - val_loss: 6.2506 - val_accuracy: 0.1847

# %%
plot_model(history,"P5.2 EMOTIW_audio_to_image arquitectura Urbansound preemphasis")
plt.figure()

# %%
train_dir= '/content/spec_images/train'
test_dir= '/content/spec_images/test'
# val_dir= '/content/spec_images/val'

def create_sets(train_dir,test_dir):

  datagen=ImageDataGenerator(rescale=1./255.)

  train_generator=datagen.flow_from_directory(
      train_dir,
      batch_size=32,
      seed=42,
      shuffle=True,
      class_mode="categorical",
      target_size=(64,64))

  # valid_generator=datagen.flow_from_directory(
  #     val_dir,
  #     batch_size=32,
  #     seed=42,
  #     shuffle=True,
  #     class_mode="categorical",
  #     target_size=(64,64))

  test_generator=datagen.flow_from_directory(
      test_dir,
      batch_size=32,
      seed=42,
      shuffle=True,
      class_mode="categorical",
      target_size=(64,64))
  
  return train_generator,test_generator

train_set,test_set=create_sets(train_dir,test_dir)
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.

# %%
 test_set=datagen.flow_from_directory(
      test_dir,
      batch_size=32,
      seed=42,
      shuffle=False,
      class_mode="categorical",
      target_size=(64,64))
 
def evaluate_model(model):
  datagen = ImageDataGenerator(rescale=1. / 255)

  predictions=model.predict(test_set)
  print(train_set.class_indices.keys())
  print('Confusion Matrix')
  ypred=[round(list(i).index(max(i))) for i in predictions]
  print(confusion_matrix(test_set.classes, ypred)[:,:])
  # print(ypred)
  print("accuracy: ",accuracy_score(test_set.classes, ypred))
  for i in range(0,6):
    print("Train: ",list(train_set.class_indices.keys())[i]," ",list(test_set.labels).count(i))
    print("Test: ",list(test_set.class_indices.keys())[i]," ",list(train_set.labels).count(i))

  print("evaluate: ",model.evaluate_generator(test_set))
  print(test_set.class_indices)
  return predictions

# %%
test_set

# %%
img_width, img_height=64,64
lr=1e-5
batch_size=16

train_generator,test_generator=create_sets(train_dir,test_dir,batch_size)
model_VGG_audio=create_model(8,dropout=0.5)
model_VGG_audio.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.SGD(lr=lr, momentum=0.9),
                metrics=['accuracy','categorical_accuracy'])

# path=filepath+"VGGTEST"+":{epoch:03d}-val_accuracy:{val_accuracy:.3f}.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

E_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                              min_delta=0,
                                              patience=20,
                                              verbose=1,
                                              mode="auto",
                                              restore_best_weights=True)
callback_list = [E_stopping]

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
# STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

history=model_VGG_audio.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_TEST,
                    epochs=60,
                    callbacks=callback_list)

path=""
plot_model(history,"vgg16 model last conv block fine tuned audio converted to spectrogram images")
title="vgg16 last conv block fine-tuned audio spectrogram images"
plt.figure()
plot_conf_matrix(test_generator,model_VGG_audio,path,title,standard_format=True,percentages=True,save_plot=True)
# Out:
# Found 773 images belonging to 7 classes.
# Found 381 images belonging to 7 classes.
# VGG_summary:
# [<keras.engine.input_layer.InputLayer object at 0x7f479be9f7d0>, <keras.layers.convolutional.Conv2D object at 0x7f48102d5250>, <keras.layers.convolutional.Conv2D object at 0x7f479bc17410>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c2ae890>, <keras.layers.convolutional.Conv2D object at 0x7f48100f8f10>, <keras.layers.convolutional.Conv2D object at 0x7f48102f2e50>, <keras.layers.pooling.MaxPooling2D object at 0x7f479c2cf110>, <keras.layers.convolutional.Conv2D object at 0x7f481036ad90>, <keras.layers.convolutional.Conv2D object at 0x7f4820431a50>, <keras.layers.convolutional.Conv2D object at 0x7f48211d3c10>, <keras.layers.pooling.MaxPooling2D object at 0x7f481036a610>, <keras.layers.convolutional.Conv2D object at 0x7f479bc0a210>, <keras.layers.convolutional.Conv2D object at 0x7f479bc0a450>, <keras.layers.convolutional.Conv2D object at 0x7f4820405350>, <keras.layers.pooling.MaxPooling2D object at 0x7f48175f2350>, <keras.layers.convolutional.Conv2D object at 0x7f482420c810>, <keras.layers.convolutional.Conv2D object at 0x7f481753b890>, <keras.layers.convolutional.Conv2D object at 0x7f4817529f50>, <keras.layers.pooling.MaxPooling2D object at 0x7f4817828910>, <keras.layers.core.Flatten object at 0x7f4727e516d0>, <keras.layers.core.Dense object at 0x7f4727e513d0>, <keras.layers.core.Dropout object at 0x7f48101c2390>, <keras.layers.core.Dense object at 0x7f472837b050>]
# freezing layer:  input_8
# freezing layer:  block1_conv1
# freezing layer:  block1_conv2
# freezing layer:  block1_pool
# freezing layer:  block2_conv1
# freezing layer:  block2_conv2
# freezing layer:  block2_pool
# freezing layer:  block3_conv1
# freezing layer:  block3_conv2
# freezing layer:  block3_conv3
# freezing layer:  block3_pool
# freezing layer:  block4_conv1
# freezing layer:  block4_conv2
# freezing layer:  block4_conv3
# freezing layer:  block4_pool
# new_model summary!
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 7)                 7175
# =================================================================
# Total params: 16,820,039
# Trainable params: 9,184,775
# Non-trainable params: 7,635,264
# _________________________________________________________________
# Epoch 1/60
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 48/48 [==============================] - 4s 61ms/step - loss: 2.1625 - accuracy: 0.1480 - categorical_accuracy: 0.1480 - val_loss: 1.9544 - val_accuracy: 0.1603 - val_categorical_accuracy: 0.1603
# Epoch 2/60
# 48/48 [==============================] - 3s 54ms/step - loss: 2.1010 - accuracy: 0.1466 - categorical_accuracy: 0.1466 - val_loss: 1.9357 - val_accuracy: 0.1793 - val_categorical_accuracy: 0.1793
# Epoch 3/60
# 48/48 [==============================] - 3s 55ms/step - loss: 2.0900 - accuracy: 0.1704 - categorical_accuracy: 0.1704 - val_loss: 1.9309 - val_accuracy: 0.1957 - val_categorical_accuracy: 0.1957
# Epoch 4/60
# 48/48 [==============================] - 3s 55ms/step - loss: 2.0788 - accuracy: 0.1480 - categorical_accuracy: 0.1480 - val_loss: 1.9280 - val_accuracy: 0.2038 - val_categorical_accuracy: 0.2038
# Epoch 5/60
# 48/48 [==============================] - 3s 54ms/step - loss: 2.0408 - accuracy: 0.1691 - categorical_accuracy: 0.1691 - val_loss: 1.9266 - val_accuracy: 0.2038 - val_categorical_accuracy: 0.2038
# Epoch 6/60
# 48/48 [==============================] - 3s 54ms/step - loss: 2.0409 - accuracy: 0.1902 - categorical_accuracy: 0.1902 - val_loss: 1.9225 - val_accuracy: 0.2147 - val_categorical_accuracy: 0.2147
# Epoch 7/60
# 48/48 [==============================] - 3s 53ms/step - loss: 2.0456 - accuracy: 0.1783 - categorical_accuracy: 0.1783 - val_loss: 1.9198 - val_accuracy: 0.2174 - val_categorical_accuracy: 0.2174
# Epoch 8/60
# 48/48 [==============================] - 3s 54ms/step - loss: 2.0217 - accuracy: 0.1902 - categorical_accuracy: 0.1902 - val_loss: 1.9163 - val_accuracy: 0.2337 - val_categorical_accuracy: 0.2337
# Epoch 9/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9658 - accuracy: 0.2166 - categorical_accuracy: 0.2166 - val_loss: 1.9134 - val_accuracy: 0.2120 - val_categorical_accuracy: 0.2120
# Epoch 10/60
# 48/48 [==============================] - 3s 54ms/step - loss: 2.0058 - accuracy: 0.1902 - categorical_accuracy: 0.1902 - val_loss: 1.9126 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 11/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9949 - accuracy: 0.1876 - categorical_accuracy: 0.1876 - val_loss: 1.9096 - val_accuracy: 0.2228 - val_categorical_accuracy: 0.2228
# Epoch 12/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9913 - accuracy: 0.1955 - categorical_accuracy: 0.1955 - val_loss: 1.9062 - val_accuracy: 0.2228 - val_categorical_accuracy: 0.2228
# Epoch 13/60
# 48/48 [==============================] - 3s 53ms/step - loss: 2.0029 - accuracy: 0.1901 - categorical_accuracy: 0.1901 - val_loss: 1.9040 - val_accuracy: 0.2201 - val_categorical_accuracy: 0.2201
# Epoch 14/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9795 - accuracy: 0.2034 - categorical_accuracy: 0.2034 - val_loss: 1.9029 - val_accuracy: 0.2255 - val_categorical_accuracy: 0.2255
# Epoch 15/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9836 - accuracy: 0.2061 - categorical_accuracy: 0.2061 - val_loss: 1.9011 - val_accuracy: 0.2201 - val_categorical_accuracy: 0.2201
# Epoch 16/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.9651 - accuracy: 0.1717 - categorical_accuracy: 0.1717 - val_loss: 1.8987 - val_accuracy: 0.2255 - val_categorical_accuracy: 0.2255
# Epoch 17/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9521 - accuracy: 0.2246 - categorical_accuracy: 0.2246 - val_loss: 1.8969 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 18/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9766 - accuracy: 0.1942 - categorical_accuracy: 0.1942 - val_loss: 1.8947 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 19/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9614 - accuracy: 0.1915 - categorical_accuracy: 0.1915 - val_loss: 1.8945 - val_accuracy: 0.2228 - val_categorical_accuracy: 0.2228
# Epoch 20/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9377 - accuracy: 0.2180 - categorical_accuracy: 0.2180 - val_loss: 1.8924 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 21/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9418 - accuracy: 0.2338 - categorical_accuracy: 0.2338 - val_loss: 1.8907 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 22/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9121 - accuracy: 0.2219 - categorical_accuracy: 0.2219 - val_loss: 1.8876 - val_accuracy: 0.2310 - val_categorical_accuracy: 0.2310
# Epoch 23/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.9350 - accuracy: 0.2180 - categorical_accuracy: 0.2180 - val_loss: 1.8847 - val_accuracy: 0.2310 - val_categorical_accuracy: 0.2310
# Epoch 24/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.8909 - accuracy: 0.2299 - categorical_accuracy: 0.2299 - val_loss: 1.8839 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 25/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9565 - accuracy: 0.1995 - categorical_accuracy: 0.1995 - val_loss: 1.8811 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 26/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.9251 - accuracy: 0.2299 - categorical_accuracy: 0.2299 - val_loss: 1.8799 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
# Epoch 27/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8705 - accuracy: 0.2351 - categorical_accuracy: 0.2351 - val_loss: 1.8786 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 28/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.8989 - accuracy: 0.2510 - categorical_accuracy: 0.2510 - val_loss: 1.8761 - val_accuracy: 0.2418 - val_categorical_accuracy: 0.2418
# Epoch 29/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8876 - accuracy: 0.2299 - categorical_accuracy: 0.2299 - val_loss: 1.8757 - val_accuracy: 0.2310 - val_categorical_accuracy: 0.2310
# Epoch 30/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8899 - accuracy: 0.2550 - categorical_accuracy: 0.2550 - val_loss: 1.8721 - val_accuracy: 0.2337 - val_categorical_accuracy: 0.2337
# Epoch 31/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8894 - accuracy: 0.2589 - categorical_accuracy: 0.2589 - val_loss: 1.8719 - val_accuracy: 0.2337 - val_categorical_accuracy: 0.2337
# Epoch 32/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.8854 - accuracy: 0.2325 - categorical_accuracy: 0.2325 - val_loss: 1.8705 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 33/60
# 48/48 [==============================] - 3s 53ms/step - loss: 1.8716 - accuracy: 0.2510 - categorical_accuracy: 0.2510 - val_loss: 1.8689 - val_accuracy: 0.2337 - val_categorical_accuracy: 0.2337
# Epoch 34/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8747 - accuracy: 0.2563 - categorical_accuracy: 0.2563 - val_loss: 1.8664 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 35/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8697 - accuracy: 0.2497 - categorical_accuracy: 0.2497 - val_loss: 1.8656 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 36/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8824 - accuracy: 0.2431 - categorical_accuracy: 0.2431 - val_loss: 1.8660 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 37/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8685 - accuracy: 0.2510 - categorical_accuracy: 0.2510 - val_loss: 1.8642 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 38/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8768 - accuracy: 0.2497 - categorical_accuracy: 0.2497 - val_loss: 1.8629 - val_accuracy: 0.2418 - val_categorical_accuracy: 0.2418
# Epoch 39/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8355 - accuracy: 0.2880 - categorical_accuracy: 0.2880 - val_loss: 1.8625 - val_accuracy: 0.2391 - val_categorical_accuracy: 0.2391
# Epoch 40/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8527 - accuracy: 0.2774 - categorical_accuracy: 0.2774 - val_loss: 1.8611 - val_accuracy: 0.2418 - val_categorical_accuracy: 0.2418
# Epoch 41/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8632 - accuracy: 0.2563 - categorical_accuracy: 0.2563 - val_loss: 1.8613 - val_accuracy: 0.2446 - val_categorical_accuracy: 0.2446
# Epoch 42/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8482 - accuracy: 0.2668 - categorical_accuracy: 0.2668 - val_loss: 1.8600 - val_accuracy: 0.2364 - val_categorical_accuracy: 0.2364
# Epoch 43/60
# 48/48 [==============================] - 3s 54ms/step - loss: 1.8198 - accuracy: 0.3052 - categorical_accuracy: 0.3052 - val_loss: 1.8578 - val_accuracy: 0.2446 - val_categorical_accuracy: 0.2446
# Epoch 44/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8434 - accuracy: 0.2589 - categorical_accuracy: 0.2589 - val_loss: 1.8562 - val_accuracy: 0.2473 - val_categorical_accuracy: 0.2473
# Epoch 45/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8318 - accuracy: 0.2919 - categorical_accuracy: 0.2919 - val_loss: 1.8553 - val_accuracy: 0.2500 - val_categorical_accuracy: 0.2500
# Epoch 46/60
# 48/48 [==============================] - 3s 55ms/step - loss: 1.8214 - accuracy: 0.2761 - categorical_accuracy: 0.2761 - val_loss: 1.8544 - val_accuracy: 0.2473 - val_categorical_accuracy: 0.2473
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 381
# [[38  0  0 14 10  2  0]
#  [16  0  0 10 13  1  0]
#  [12  0  0 19  9  6  0]
#  [23  0  0 19 20  1  0]
#  [13  0  0 10 35  3  0]
#  [11  0  0 28 22  0  0]
#  [10  0  0 13 19  4  0]]
#
# accuracy:  0.24146981627296588
# f1 score: [0.40641711 0.         0.         0.21590909 0.37037037 0.
#  0.        ]
# f1 score weighted: 0.16326918768249632
# ---------------------------------------------------------
# vgg16 last conv block fine-tuned audio spectrogram images

# %%
plot_model(history,"Model1AudioImatges")
# audio_model.save("/content/gdrive/MyDrive/TFM_MUSI/combined_model/model1imatges.h5")
