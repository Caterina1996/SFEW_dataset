# %% [markdown]
# <a href="https://colab.research.google.com/github/Caterina1996/SFEW_dataset/blob/TFM_entrega/combinedmodel0_2set_vf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import glob, os,shutil

import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
from numpy import save
from numpy.random import seed
from numpy import asarray

import librosa                    
import librosa.display
import IPython.display as ipd
import scipy.io.wavfile
from scipy.fftpack import dct

import tensorflow as tf
from tensorflow.random import set_seed

import operator
import keras
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Conv2D, BatchNormalization, MaxPooling2D
from keras import applications
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.callbacks import ModelCheckpoint,CSVLogger
from keras import regularizers

from sklearn.metrics import confusion_matrix
import itertools

from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import sklearn.metrics as sk_metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

import pickle 
import pandas as pd
import csv

from csv import writer
from csv import DictWriter
from sklearn.model_selection import GridSearchCV
# from tensorflow.keras import layers

# %%
#Set seed
seed(42)
tf.random.set_seed(42)

# %%
N_OUTPUT_LABELS=7
lr=0.001
batch_size=8

emotions_dict={
 0: 'Angry',
 1: 'Disgust',
 2: 'Fear',
 3: 'Happy',
 4: 'Neutral',
 5: 'Sad',
 6: 'Surprise'}

emotions_reversed_dict = {v: k for k, v in emotions_dict.items() }

def get_emo(prediction):
  emo=list(prediction).index(max(prediction))
  return emotions_dict[emo]

def get_emo_value(prediction):
  return list(prediction).index(max(prediction))

def get_one_hot_pred(prediction):
  one_hot_label=[0]*7
  emo=list(prediction).index(max(prediction))
  one_hot_label[emo]=1
  return one_hot_label

# %%
emotions_reversed_dict
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
labels_dirs=["/content/train_video_labels.pkl","/content/val_video_labels.pkl"]

with open(labels_dirs[0], 'rb') as f:
  train_labels = pickle.load(f)

with open(labels_dirs[1], 'rb') as f:
  val_labels = pickle.load(f)

#AUDIO predictions with VGG model trained with Spectrograms converted into images
audio_preds=["/content/vgg_audio_model_preds_train.pkl","/content/vgg_audio_model_preds_test.pkl"]

with open(audio_preds[0], 'rb') as f:
  audio_train_preds = pickle.load(f)

with open(audio_preds[1], 'rb') as f:
  audio_test_preds = pickle.load(f)

#VIDEO predictions with AFEW video images predicted with VGG16 model trained with the SFEW images
# video_preds=["/content/afew_videos_imgs_predictions_m2_tr.pkl","/content/afew_videos_imgs_predictions_m2_val.pkl","/content/afew_videos_imgs_predictions_m2_te.pkl"]

video_preds=["/content/afew_videos_imgs_predictions_dict_m3_tr.pkl","/content/afew_videos_imgs_predictions_dict__bo_m3_te.pkl"]

with open(video_preds[0], 'rb') as f:
  video_train_preds = pickle.load(f)

with open(video_preds[1], 'rb') as f:
  video_test_preds = pickle.load(f)

#VIDEO with SFEW video images predicted with VGG16 model trained with the SFEW images
sfew_preds=["/content/sfew_predictions_tr.pkl","/content/sfew_predictions_te.pkl"]

with open(sfew_preds[0], 'rb') as f:
  sfew_video_train_preds = pickle.load(f)

with open(sfew_preds[1], 'rb') as f:
  sfew_video_test_preds = pickle.load(f)

# %%
print(len(train_labels))
print(len(val_labels))
print("_____________")

print(len(audio_train_preds))
print(len(audio_test_preds))
print("_____________")

print(len(video_train_preds))
print(len(video_test_preds))

print("_____________")
print(len(sfew_video_train_preds))
print(len(sfew_video_test_preds))
# Out:
# 773
# 381
# _____________
# 773
# 381
# _____________
# 756
# 370
# _____________
# 378
# 188

# %%
labels=list(emotions_reversed_dict.keys())
def plot_metrics(y_true,ypred,standard_format=True,percentages=True,path="",save_plot=True):
  print(confusion_matrix(y_true, ypred)[:,:])
  print("")
  f1=f1_score(y_true, ypred,average=None)
  f1_w=f1_score(y_true, ypred,average='weighted')
  ac=accuracy_score(y_true, ypred)
  print("accuracy: ",ac)
  print("f1 score:",f1)
  print("f1 score weighted:",f1_w)
  print("---------------------------------------------------------")
  print(path)
  if standard_format:
    cm = confusion_matrix(y_true, ypred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues,xticks_rotation='vertical',values_format='d')
    if save_plot:
      plt.savefig(path+".png")
    plt.show()
  print("")
  if percentages:
    cm = confusion_matrix(y_true, ypred,normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues,xticks_rotation='vertical',values_format='.2f')
    plt.show()
    if save_plot:
      plt.savefig(path+"_perctg.png")
    plt.show()
  print("")

# %%
#test 0 obtain accuracy and confussion matrix of each set of predictions:

#Test set audio:
print("audio")
predictions,real_labels=[],[]
for audio_id in audio_test_preds.keys():
  predictions.append(get_emo(audio_test_preds[audio_id][0]))
  real_labels.append(val_labels[audio_id])
  
numeric_real_label=[emotions_reversed_dict[label] for label in real_labels]
numeric_preds=[emotions_reversed_dict[pred] for pred in predictions]

plot_metrics(numeric_real_label,numeric_preds,standard_format=True,percentages=True,path="audio")

print("_______________________________________________")
print("VIDEO:")
#Test set video:

predictions,real_labels=[],[]
for id in video_test_preds.keys():
  predictions.append(get_emo(video_test_preds[id][0]))
  real_labels.append(val_labels[id])
  
numeric_real_label=[emotions_reversed_dict[label] for label in real_labels]
numeric_preds=[emotions_reversed_dict[pred] for pred in predictions]

plot_metrics(numeric_real_label,numeric_preds,standard_format=True,percentages=True,path="video_afew_frames")

print("-------------------------------------------")
print("sfew images:")

predictions,real_labels=[],[]
for id in sfew_video_test_preds.keys():
  predictions.append(get_emo(sfew_video_test_preds[id][0]))
  real_labels.append(val_labels[id])

numeric_real_label=[emotions_reversed_dict[label] for label in real_labels]
numeric_preds=[emotions_reversed_dict[pred] for pred in predictions]

plot_metrics(numeric_real_label,numeric_preds,standard_format=True,percentages=True,path="video_afew_frames")
# Out:
# audio
# [[31  3  1 22  3  4  0]
#  [ 8  6  1 13  4  8  0]
#  [ 8  2  9 16  4  4  3]
#  [10  6  6 26  5  9  1]
#  [10  4  2 26 15  4  0]
#  [ 7  5  8 16  7 13  5]
#  [ 6  1  4 18  7  5  5]]
#
# accuracy:  0.2755905511811024
# f1 score: [0.43055556 0.17910448 0.23376623 0.26       0.28301887 0.24074074
#  0.16666667]
# f1 score weighted: 0.26632279319823626
# ---------------------------------------------------------
# audio
# _______________________________________________
# VIDEO:
# [[43  0  0  1  5 10  0]
#  [18  0  0  2  2 17  0]
#  [32  0  0  1  1 10  0]
#  [22  0  0  9  5 25  2]
#  [20  0  0  0  6 33  1]
#  [24  0  0  1  7 26  1]
#  [27  0  0  0  1 18  0]]
#
# accuracy:  0.22702702702702704
# f1 score: [0.35102041 0.         0.         0.23376623 0.13793103 0.26262626
#  0.        ]
# f1 score weighted: 0.1600224010076227
# ---------------------------------------------------------
# video_afew_frames
# -------------------------------------------
# sfew images:
# [[25  0  0  7  2  0  1]
#  [ 5  0  0  9  5  2  1]
#  [ 9  1  0  5  2  2  4]
#  [ 3  0  0 25  4  2  1]
#  [ 4  0  0  1 12  1  4]
#  [ 7  0  0  2  8  8  3]
#  [ 8  0  0  5  6  0  4]]
#
# accuracy:  0.39361702127659576
# f1 score: [0.52083333 0.         0.         0.56179775 0.39344262 0.37209302
#  0.19512195]
# f1 score weighted: 0.3268842300484621
# ---------------------------------------------------------
# video_afew_frames

# %%
#Extract train features:
#Vector de features de video concatenadas con audio

feature_vectors,feature_labels=[],[]

for id in list(video_train_preds.keys()):
  feature=np.append(video_train_preds[id][0], audio_train_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[train_labels[id]])

x_train=feature_vectors
y_train=tf.keras.utils.to_categorical(feature_labels)

#Extract val features:
feature_vectors,feature_labels=[],[]

for id in list(video_test_preds.keys()):
  feature=np.append(video_test_preds[id][0], audio_test_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[val_labels[id]])

x_val=feature_vectors
y_val=tf.keras.utils.to_categorical(feature_labels)

# %%
# feature_labels
#avg acc
(39+27)/2
# Out:
# 33.0

# %%
# TEST 0 promig audio i video:
#prediccions video amb frames sfew

audio_preds_sum,video_preds_sum=[],[]
predictions,real_labels,feature_keys=[],[],[]

feature_vectors_dict={}

for id in sfew_video_test_preds.keys():

  #test de que esten normalizados
  audio_preds_sum.append(np.sum(audio_test_preds[id]))
  video_preds_sum.append(np.sum(sfew_video_test_preds[id][0]))

  #media de las predicciones
  avgd_pred=(sfew_video_test_preds[id]+audio_test_preds[id][0])/2
  predictions.append(get_emo(avgd_pred[0]))
  real_labels.append(val_labels[id])
  
print(set(audio_preds_sum))
print(set(video_preds_sum))
print(" ")
plot_metrics(real_labels,predictions,standard_format=True,percentages=True,path="video_afew_frames")
##REVISAR xq las probabilidades del video suman más de 1 !!
# Out:
# {0.99999994, 1.0, 0.9999998, 1.0000001, 0.9999999}
# {0.9999999841675162, 1.000000029336661, 1.00000002712477, 1.000000013038516, 1.0000000023283064, 0.9999999944120646, 1.0000000185100362, 1.0000000335276127, 1.0000000298023224, 0.9999999636784196, 0.9999999897554517, 1.0000000009313226, 0.9999999608844519, 0.9999999972060323, 0.9999999860301614, 0.9999999981373549, 0.9999999739229679, 0.9999999515712261, 1.0000000252621248, 0.9999999590218067,
0.999999991232722, 0.9999999822144959, 1.000000004213393, 0.9999999974412148, 0.9999999925063027, 0.9999999970762578, 1.000000000953615, 0.999999993144175, 1.0000000014089239, 0.9999999984650424, 0.9999999905537282, 1.0000000083652725, 1.0000000007982766, 1.0000000019624298, 0.9999999973501655, 1.0000000029824496, 0.9999999973095125, 0.9999999960612816, 0.999999995653828, 0.99999999635232, 0.9999999976957795, 0.9999999974416681, 0.9999999992119578, 0.9999999920687367, 0.9999999998743453, 0.9999999912189587, 1.0000000088130712, 0.9999999979200462, 1.0000000011796752, 1.000000001099924, 0.999999998054378, 0.9999999950536423, 1.0000000010783734, 0.9999999975183661, 1.0000000011514534, 0.9999999971528138, 0.9999999977331959, 0.999999993122541, 0.9999999949851861, 0.9999999956960238, 0.9999999962342173, 0.9999999960511923, 0.9999999983794987, 1.0000000055000748, 0.9999999938703769, 0.9999999974906029, 1.0000000029611282, 1.0000000023800464, 1.000000015622936, 1.0000000054352596, 1.0000000059604643, 0.9999999972725554, 0.9999999994393981, 1.0000000010303993, 1.0000000085539953, 1.0000000090748515, 0.9999999952657769, 1.000000000576533, 0.9999999997756877, 0.9999999941242013, 1.0000000036632022, 1.000000002739184, 0.9999999942417005, 0.9999999966508206, 1.0000000167904155, 0.9999999929432194, 0.9999999971250476, 1.0000000025088691, 0.9999999998536493, 1.0000000083129164, 0.9999999891285998, 1.0000000101558508, 0.9999999958977459, 0.9999999911798274, 0.999999992346027, 1.0000000028732292, 1.000000007748604, 1.00000000246628, 1.000000006068618, 0.9999999969208146, 1.0000000098720192, 0.9999999931751518, 0.9999999879548946, 1.000000004478566, 1.0000000000262346, 1.00000000063465 ...
#
# [[41  0  0  4  4 10  0]
#  [10  2  0 10  4 13  0]
#  [19  0  4  4  5 10  2]
#  [20  3  2 17  5 16  0]
#  [14  2  1  6 18 19  0]
#  [15  1  2  4  8 25  4]
#  [18  1  1  6  5 13  2]]
#
# accuracy:  0.2945945945945946
# f1 score: [0.41836735 0.08333333 0.14814815 0.29824561 0.33027523 0.3030303
#  0.07407407]
# f1 score weighted: 0.2549847965399458
# ---------------------------------------------------------
# video_afew_frames

# %%
#Extract train features:
#Vector de features de video concatenadas con audio

feature_vectors,feature_labels=[],[]

for id in list(sfew_video_train_preds.keys()):
  feature=np.append(sfew_video_train_preds[id][0], audio_train_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[train_labels[id]])

x_train=feature_vectors
y_train=tf.keras.utils.to_categorical(feature_labels)

#Extract val features:
feature_vectors,feature_labels=[],[]

for id in list(sfew_video_test_preds.keys()):
  feature=np.append(sfew_video_test_preds[id][0], audio_test_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[val_labels[id]])

x_test=feature_vectors
y_test=tf.keras.utils.to_categorical(feature_labels)

# %%
print(len(x_test))
print(len(x_train))
print(len(y_test))
print(len(y_train))
# Out:
# 188
# 378
# 188
# 378

# %%
def plot_model(history,title):
  plt.figure()
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  # plt.plot(history.history['val_categorical_accuracy'])
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.title("model train and val accuracy from "+title)
  # plt.savefig("Combinedmodel1.png")
  # plt.show()
  
  plt.figure()
  plt.plot(history.history['val_accuracy'])
  plt.title("Validation accuracy " + title)

  plt.figure()
  plt.plot(history.history['val_categorical_accuracy'])
  plt.title("Validation categorical accuracy"+title)

# %%
print(asarray(x_train).shape)
print(asarray(x_test).shape)
print(asarray(y_train).shape)
print(asarray(y_test).shape)

x_train=asarray(x_train)
x_test=asarray(x_test)
y_train=asarray(y_train)
y_test=asarray(y_test)
# Out:
# (378, 14)
# (188, 14)
# (378, 7)
# (188, 7)

# %%
def model1():
  #Model 1
  model = Sequential()
  model.add(Dense(units=28,input_dim=14,activation='relu'))
  model.add(Dropout(0.25))
  # model.add(BatchNormalization())
  model.add(Dense(units=N_OUTPUT_LABELS,
                  activation='softmax'))
  model.summary()

  optimizer = tf.keras.optimizers.RMSprop(learning_rate=lr)
  model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy', metrics=['categorical_accuracy','accuracy'])
  return model

# %%
#Model 1
model = Sequential()
model.add(Dense(units=28,input_dim=14,activation='relu'))
model.add(Dropout(0.25))
# model.add(BatchNormalization())
model.add(Dense(units=N_OUTPUT_LABELS,
                activation='softmax'))
model.summary()

optimizer = tf.keras.optimizers.RMSprop(learning_rate=lr)
model.compile(optimizer=optimizer,
                loss='categorical_crossentropy', metrics=['categorical_accuracy','accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 28)                420
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 203
# =================================================================
# Total params: 623
# Trainable params: 623
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr=0.001
batch_size=8
epochs=50
# model=model1()
history=model.fit(x_train, y_train,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  batch_size=batch_size)

plot_model(history,"test 1 combined model sfew frames")
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 6ms/step - loss: 1.9473 - categorical_accuracy: 0.1296 - accuracy: 0.1296 - val_loss: 1.9143 - val_categorical_accuracy: 0.2128 - val_accuracy: 0.2128
# Epoch 2/50
# 48/48 [==============================] - 0s 2ms/step - loss: 1.8439 - categorical_accuracy: 0.3360 - accuracy: 0.3360 - val_loss: 1.8753 - val_categorical_accuracy: 0.3298 - val_accuracy: 0.3298
# Epoch 3/50
# 48/48 [==============================] - 0s 2ms/step - loss: 1.7366 - categorical_accuracy: 0.4656 - accuracy: 0.4656 - val_loss: 1.8403 - val_categorical_accuracy: 0.3404 - val_accuracy: 0.3404
# Epoch 4/50
# 48/48 [==============================] - 0s 2ms/step - loss: 1.6465 - categorical_accuracy: 0.5344 - accuracy: 0.5344 - val_loss: 1.8056 - val_categorical_accuracy: 0.3670 - val_accuracy: 0.3670
# Epoch 5/50
# 48/48 [==============================] - 0s 2ms/step - loss: 1.5652 - categorical_accuracy: 0.5582 - accuracy: 0.5582 - val_loss: 1.7743 - val_categorical_accuracy: 0.3670 - val_accuracy: 0.3670
# Epoch 6/50
# 48/48 [==============================] - 0s 2ms/step - loss: 1.4742 - categorical_accuracy: 0.5767 - accuracy: 0.5767 - val_loss: 1.7451 - val_categorical_accuracy: 0.3617 - val_accuracy: 0.3617
50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5911 - categorical_accuracy: 0.8095 - accuracy: 0.8095 - val_loss: 1.8527 - val_categorical_accuracy: 0.4521 - val_accuracy: 0.4521
# Epoch 46/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5436 - categorical_accuracy: 0.8466 - accuracy: 0.8466 - val_loss: 1.8637 - val_categorical_accuracy: 0.4521 - val_accuracy: 0.4521
# Epoch 47/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5840 - categorical_accuracy: 0.8228 - accuracy: 0.8228 - val_loss: 1.8722 - val_categorical_accuracy: 0.4415 - val_accuracy: 0.4415
# Epoch 48/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5576 - categorical_accuracy: 0.8201 - accuracy: 0.8201 - val_loss: 1.8715 - val_categorical_accuracy: 0.4415 - val_accuracy: 0.4415
# Epoch 49/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.5561 - categorical_accuracy: 0.8254 - accuracy: 0.8254 - val_loss: 1.8755 - val_categorical_accuracy: 0.4362 - val_accuracy: 0.4362
# Epoch 50/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5411 - categorical_accuracy: 0.8228 - accuracy: 0.8228 - val_loss: 1.8897 - val_categorical_accuracy: 0.4521 - val_accuracy: 0.4521

# %%
predictions=model.predict(x_test)

labels=[key for key in emotions_reversed_dict.keys()]
ypred=[round(list(i).index(np.max(i))) for i in predictions]
y_true=[np.argmax(y) for y in y_test]
plot_metrics(y_true,ypred,standard_format=True,percentages=True,path="modelo1 combinación",save_plot=True)
# Out:
# [[19  4  0  6  1  3  2]
#  [ 5  9  0  4  2  1  1]
#  [ 2  2  6  3  4  3  3]
#  [ 3  6  1 19  2  4  0]
#  [ 0  4  0  2 13  1  2]
#  [ 3  3  4  2  3 11  2]
#  [ 1  2  1  2  6  3  8]]
#
# accuracy:  0.4521276595744681
# f1 score: [0.55882353 0.34615385 0.34285714 0.52054795 0.49056604 0.40740741
#  0.3902439 ]
# f1 score weighted: 0.44922643886380903
# ---------------------------------------------------------
# modelo1 combinación

# %%
# SVM test:

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_val)
y_true_tr=[ get_emo_value(pred) for pred in y_train]
y_true_te=[ get_emo_value(pred) for pred in y_val]

rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))
print("f1: ",f1_score(y_true_te, rbf_pred,average='weighted'))
# Out:
# accuracy:  0.23404255319148937
# [[10  0  0 25  0  0  0]
#  [ 2  0  0 20  0  0  0]
#  [ 2  0  0 21  0  0  0]
#  [ 3  0  0 31  1  0  0]
#  [ 0  0  0 19  3  0  0]
#  [ 1  0  0 27  0  0  0]
#  [ 1  0  0 21  1  0  0]]
# f1:  0.15295943864317646

# %%
# Performing CV to tune parameters for best SVM fit 

from sklearn.svm import SVC
C_range = [1, 10, 100]
gamma_range = [ 1e-1,1,1e2]

params_grid = [{'kernel': ['rbf'], 'gamma': gamma_range,
                     'C': C_range},{'kernel': ['poly'],'degree':[7], 'C': C_range}]


# 
svm_model = GridSearchCV(SVC(), params_grid)
svm_model.fit(X_train_scaled, y_true_tr)

print("The best parameters are %s with a score of %0.2f"
      % (svm_model.best_params_, svm_model.best_score_))
# Out:
# The best parameters are {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'} with a score of 0.80

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.1, C=1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))

f1_score(y_true_te, rbf_pred, average='weighted')

plot_metrics(y_true_te,rbf_pred,standard_format=True,percentages=True,path="modelo1 combinación",save_plot=True)
# Out:
# accuracy:  0.39893617021276595
# [[17  4  1  6  1  5  1]
#  [ 4  7  0  7  2  2  0]
#  [ 3  3  4  2  5  3  3]
#  [ 4  8  1 17  2  3  0]
#  [ 0  4  0  2 13  2  1]
#  [ 2  4  4  3  3 11  1]
#  [ 1  3  1  4  4  4  6]]
# [[17  4  1  6  1  5  1]
#  [ 4  7  0  7  2  2  0]
#  [ 3  3  4  2  5  3  3]
#  [ 4  8  1 17  2  3  0]
#  [ 0  4  0  2 13  2  1]
#  [ 2  4  4  3  3 11  1]
#  [ 1  3  1  4  4  4  6]]
#
# accuracy:  0.39893617021276595
# f1 score: [0.51515152 0.25454545 0.23529412 0.44736842 0.5        0.37931034
#  0.34285714]
# f1 score weighted: 0.3947147149676286
# ---------------------------------------------------------
# modelo1 combinación

# %%
# test con el modelo con los frames del afew:

#Extract train features:
#Vector de features de video concatenadas con audio

feature_vectors,feature_labels=[],[]

for id in list(video_train_preds.keys()):
  feature=np.append(video_train_preds[id][0], audio_train_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[train_labels[id]])

x_train=feature_vectors
y_train=tf.keras.utils.to_categorical(feature_labels)

#Extract val features:
feature_vectors,feature_labels=[],[]

for id in list(video_test_preds.keys()):
  feature=np.append(video_test_preds[id][0], audio_test_preds[id][0] )
  feature_vectors.append(feature)
  feature_labels.append(emotions_reversed_dict[val_labels[id]])

x_test=feature_vectors
y_test=tf.keras.utils.to_categorical(feature_labels)
print(asarray(x_train).shape)
print(asarray(x_test).shape)
print(asarray(y_train).shape)
print(asarray(y_test).shape)

x_train=asarray(x_train)
x_test=asarray(x_test)
y_train=asarray(y_train)
y_test=asarray(y_test)
# Out:
# (756, 14)
# (370, 14)
# (756, 7)
# (370, 7)

# %%
# TEST 0 promig audio i video:
#prediccions video amb frames sfew

audio_preds_sum,video_preds_sum=[],[]
predictions,real_labels,feature_keys=[],[],[]

feature_vectors_dict={}

for id in video_test_preds.keys():

  #test de que esten normalizados
  audio_preds_sum.append(np.sum(audio_test_preds[id]))
  video_preds_sum.append(np.sum(video_test_preds[id][0]))

  #media de las predicciones
  avgd_pred=(video_test_preds[id]+audio_test_preds[id][0])/2
  predictions.append(get_emo(avgd_pred[0]))
  real_labels.append(val_labels[id])
  
print(set(audio_preds_sum))
print(set(video_preds_sum))
print(" ")
plot_metrics(real_labels,predictions,standard_format=True,percentages=True,path="video_afew_frames")
# Out:
0000000011514534, 0.9999999971528138, 0.9999999977331959, 0.999999993122541, 0.9999999949851861, 0.9999999956960238, 0.9999999962342173, 0.9999999960511923, 0.9999999983794987, 1.0000000055000748, 0.9999999938703769, 0.9999999974906029, 1.0000000029611282, 1.0000000023800464, 1.000000015622936, 1.0000000054352596, 1.0000000059604643, 0.9999999972725554, 0.9999999994393981, 1.0000000010303993, 1.0000000085539953, 1.0000000090748515, 0.9999999952657769, 1.000000000576533, 0.9999999997756877, 0.9999999941242013, 1.0000000036632022, 1.000000002739184, 0.9999999942417005, 0.9999999966508206, 1.0000000167904155, 0.9999999929432194, 0.9999999971250476, 1.0000000025088691, 0.9999999998536493, 1.0000000083129164, 0.9999999891285998, 1.0000000101558508, 0.9999999958977459, 0.9999999911798274, 0.999999992346027, 1.0000000028732292, 1.000000007748604, 1.00000000246628, 1.000000006068618, 0.9999999969208146, 1.0000000098720192, 0.9999999931751518, 0.9999999879548946, 1.000000004478566, 1.0000000000262346, 1.00000000063465 ...
#
# [[41  0  0  4  4 10  0]
#  [10  2  0 10  4 13  0]
#  [19  0  4  4  5 10  2]
#  [20  3  2 17  5 16  0]
#  [14  2  1  6 18 19  0]
#  [15  1  2  4  8 25  4]
#  [18  1  1  6  5 13  2]]
#
# accuracy:  0.2945945945945946
# f1 score: [0.41836735 0.08333333 0.14814815 0.29824561 0.33027523 0.3030303
#  0.07407407]
# f1 score weighted: 0.2549847965399458
# ---------------------------------------------------------
# video_afew_frames

# %%
lr=0.001
batch_size=8
epochs=50
model=model1()
history=model.fit(x_train, y_train,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  batch_size=batch_size)

plot_model(history," combined sequential model1 trained on set 2 (afew frames)")
predictions=model.predict(x_test)

labels=[key for key in emotions_reversed_dict.keys()]
ypred=[round(list(i).index(np.max(i))) for i in predictions]
y_true=[np.argmax(y) for y in y_test]
plot_metrics(y_true,ypred,standard_format=True,percentages=True,path="modelo1 combinación",save_plot=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 28)                420
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 28)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 203
# =================================================================
# Total params: 623
# Trainable params: 623
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 95/95 [==============================] - 1s 4ms/step - loss: 1.8611 - categorical_accuracy: 0.3373 - accuracy: 0.3373 - val_loss: 1.9046 - val_categorical_accuracy: 0.2541 - val_accuracy: 0.2541
# Epoch 2/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1.7281 - categorical_accuracy: 0.5185 - accuracy: 0.5185 - val_loss: 1.8734 - val_categorical_accuracy: 0.2730 - val_accuracy: 0.2730
# Epoch 3/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1.6102 - categorical_accuracy: 0.5384 - accuracy: 0.5384 - val_loss: 1.8507 - val_categorical_accuracy: 0.2865 - val_accuracy: 0.2865
# Epoch 4/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1.4896 - categorical_accuracy: 0.5833 - accuracy: 0.5833 - val_loss: 1.8361 - val_categorical_accuracy: 0.2946 - val_accuracy: 0.2946
# Epoch 5/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1.3807 - categorical_accuracy: 0.6071 - accuracy: 0.6071 - val_loss: 1.8280 - val_categorical_accuracy: 0.3000 - val_accuracy: 0.3000
# Epoch 6/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1.2878 - categorical_accuracy: 0.6243 - accuracy: 0.6243 - val_loss: 1.8271 - val_categorical_accuracy: 0.3027 - val_accuracy: 0.3027
# Epoch 7/50
# 95/95 [==============================] - 0s 2ms/step - loss: 1
- val_categorical_accuracy: 0.3054 - val_accuracy: 0.3054
# Epoch 35/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6750 - categorical_accuracy: 0.7884 - accuracy: 0.7884 - val_loss: 2.4042 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 36/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7026 - categorical_accuracy: 0.7831 - accuracy: 0.7831 - val_loss: 2.4113 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 37/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6751 - categorical_accuracy: 0.7884 - accuracy: 0.7884 - val_loss: 2.4237 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 38/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7026 - categorical_accuracy: 0.7685 - accuracy: 0.7685 - val_loss: 2.4341 - val_categorical_accuracy: 0.3027 - val_accuracy: 0.3027
# Epoch 39/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6702 - categorical_accuracy: 0.7989 - accuracy: 0.7989 - val_loss: 2.4460 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 40/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6692 - categorical_accuracy: 0.7923 - accuracy: 0.7923 - val_loss: 2.4576 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 41/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6804 - categorical_accuracy: 0.7817 - accuracy: 0.7817 - val_loss: 2.4633 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 42/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.6778 - categorical_accuracy: 0.7870 - accuracy: 0.7870 - val_loss: 2.4782 - val_categorical_accuracy: 0.3054 - val_accuracy: 0.3054
# Epoch 43/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6605 - categorical_accuracy: 0.7831 - accuracy: 0.7831 - val_loss: 2.4759 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 44/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6538 - categorical_accuracy: 0.7884 - accuracy: 0.7884 - val_loss: 2.4909 - val_categorical_accuracy: 0.3135 - val_accuracy: 0.3135
# Epoch 45/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6491 - categorical_accuracy: 0.7963 - accuracy: 0.7963 - val_loss: 2.5144 - val_categorical_accuracy: 0.3135 - val_accuracy: 0.3135
# Epoch 46/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6844 - categorical_accuracy: 0.7817 - accuracy: 0.7817 - val_loss: 2.5187 - val_categorical_accuracy: 0.3135 - val_accuracy: 0.3135
# Epoch 47/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6411 - categorical_accuracy: 0.7844 - accuracy: 0.7844 - val_loss: 2.5253 - val_categorical_accuracy: 0.3108 - val_accuracy: 0.3108
# Epoch 48/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6572 - categorical_accuracy: 0.7804 - accuracy: 0.7804 - val_loss: 2.5289 - val_categorical_accuracy: 0.3081 - val_accuracy: 0.3081
# Epoch 49/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6614 - categorical_accuracy: 0.7976 - accuracy: 0.7976 - val_loss: 2.5333 - val_categorical_accuracy: 0.3108 - val_accuracy: 0.3108
# Epoch 50/50
# 95/95 [==============================] - 0s 2ms/step - loss: 0.6581 - categorical_accuracy: 0.7937 - accuracy: 0.7937 - val_loss: 2.5515 - val_categorical_accuracy: 0.3108 - val_accuracy: 0.3108
# [[28  6  1 10  4  7  3]
#  [ 8  8  1 11  3  8  0]
#  [ 8  4  9  6  6  3  8]
#  [ 7 10  6 23  5 10  2]
#  [ 7  6  2 11 23  8  3]
#  [ 5  5  9  8 10 17  5]
#  [ 5  3  4 14  5  8  7]]
#
# accuracy:  0.3108108108108108
# f1 score: [0.44094488 0.19753086 0.23684211 0.31506849 0.39655172 0.28333333
#  0.18918919]
# f1 score weighted: 0.3059521412241003
# ---------------------------------------------------------
# modelo1 combinación

# %%
plot_model(history," combined sequential model1 trained on set 2 (afew frames)")

# %%
lr=0.001
batch_size=8
epochs=50
model=model1()
history=model.fit(x_train, y_train,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  batch_size=batch_size)

plot_model(history," combined sequential model1 trained on set 2 (afew frames)")
predictions=model.predict(x_test)

labels=[key for key in emotions_reversed_dict.keys()]
ypred=[round(list(i).index(np.max(i))) for i in predictions]
y_true=[np.argmax(y) for y in y_test]
plot_metrics(y_true,ypred,standard_format=True,percentages=True,path="modelo1 combinación",save_plot=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None,
- val_categorical_accuracy: 0.3054 - val_accuracy: 0.3054
# [[27  6  1  9  3  8  5]
#  [ 8  8  1 11  3  8  0]
#  [ 8  4 10  6  5  4  7]
#  [ 7 10  6 22  5 10  3]
#  [ 8  6  2 10 23  8  3]
#  [ 5  5  9  9  9 16  6]
#  [ 5  4  4 13  5  8  7]]
#
# accuracy:  0.3054054054054054
# f1 score: [0.42519685 0.19512195 0.25974026 0.30769231 0.40707965 0.26446281
#  0.18181818]
# f1 score weighted: 0.30243588646972547
# ---------------------------------------------------------
# modelo1 combinación

# %%
# SVM test:

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_val)
y_true_tr=[ get_emo_value(pred) for pred in y_train]
y_true_te=[ get_emo_value(pred) for pred in y_val]

rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))
print("f1: ",f1_score(y_true_te, rbf_pred,average='weighted'))
# Out:
# accuracy:  0.19148936170212766
# [[ 0  0  0 35  0  0  0]
#  [ 0  0  0 22  0  0  0]
#  [ 0  0  0 23  0  0  0]
#  [ 0  0  0 35  0  0  0]
#  [ 0  0  0 21  1  0  0]
#  [ 0  0  0 28  0  0  0]
#  [ 0  0  0 23  0  0  0]]
# f1:  0.06887808252285588

# %%
# Performing CV to tune parameters for best SVM fit 

from sklearn.svm import SVC
C_range = [1, 10, 100]
gamma_range = [ 1e-1,1,1e2]

params_grid = [{'kernel': ['rbf'], 'gamma': gamma_range,
                     'C': C_range},{'kernel': ['poly'],'degree':[7], 'C': C_range}]


# 
svm_model = GridSearchCV(SVC(), params_grid)
svm_model.fit(X_train_scaled, y_true_tr)

print("The best parameters are %s with a score of %0.2f"
      % (svm_model.best_params_, svm_model.best_score_))
# Out:
# The best parameters are {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'} with a score of 0.79

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.1, C=1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))

f1_score(y_true_te, rbf_pred, average='weighted')

plot_metrics(y_true_te,rbf_pred,standard_format=True,percentages=True,path="modelo1 combinación",save_plot=True)
# Out:
# accuracy:  0.35106382978723405
# [[13  2  1 13  2  2  2]
#  [ 4  5  0 11  1  1  0]
#  [ 3  2  4  8  3  1  2]
#  [ 2  4  1 26  1  1  0]
#  [ 1  5  0  2 12  1  1]
#  [ 2  4  4  8  4  4  2]
#  [ 2  1  2  8  4  4  2]]
# [[13  2  1 13  2  2  2]
#  [ 4  5  0 11  1  1  0]
#  [ 3  2  4  8  3  1  2]
#  [ 2  4  1 26  1  1  0]
#  [ 1  5  0  2 12  1  1]
#  [ 2  4  4  8  4  4  2]
#  [ 2  1  2  8  4  4  2]]
#
# accuracy:  0.35106382978723405
# f1 score: [0.41935484 0.22222222 0.22857143 0.46846847 0.48979592 0.19047619
#  0.125     ]
# f1 score weighted: 0.320232399120648
# ---------------------------------------------------------
# modelo1 combinación

# %%
# SVM test:

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_val)
y_true_tr=[ get_emo_value(pred) for pred in y_train]
y_true_te=[ get_emo_value(pred) for pred in y_val]

rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))
print("f1: ",f1_score(y_true_te, rbf_pred,average='weighted'))
# Out:
# accuracy:  0.1837837837837838
# [[ 5  0  0 54  0  0  0]
#  [ 1  0  0 37  1  0  0]
#  [ 2  0  0 42  0  0  0]
#  [ 2  0  0 60  1  0  0]
#  [ 1  0  0 56  3  0  0]
#  [ 0  0  0 57  2  0  0]
#  [ 0  0  0 45  1  0  0]]
# f1:  0.08644205038066932

# %%
# Performing CV to tune parameters for best SVM fit 

from sklearn.svm import SVC
C_range = [1, 10, 100]
gamma_range = [ 1e-1,1,1e2]

params_grid = [{'kernel': ['rbf'], 'gamma': gamma_range,
                     'C': C_range},{'kernel': ['poly'],'degree':[7], 'C': C_range}]


# 
svm_model = GridSearchCV(SVC(), params_grid)
svm_model.fit(X_train_scaled, y_true_tr)

print("The best parameters are %s with a score of %0.2f"
      % (svm_model.best_params_, svm_model.best_score_))
# Out:
# The best parameters are {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'} with a score of 0.79

# %%
svm_model.cv_results_
# Out:
# <function sklearn.metrics._scorer._passthrough_scorer>

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.1, C=1).fit(X_train_scaled, y_true_tr)
rbf_pred = rbf.predict(X_test_scaled)

print("accuracy: ",accuracy_score(y_true_te, rbf_pred))
print(confusion_matrix(y_true_te, rbf_pred))

f1_score(y_true_te, rbf_pred, average='weighted')
# Out:
# accuracy:  0.2972972972972973
# [[23  7  2 10  4  8  5]
#  [ 7  8  1 11  4  7  1]
#  [10  9  7  5  5  2  6]
#  [ 6 11  5 24  6  9  2]
#  [ 8  6  2 11 24  6  3]
#  [ 7  6  7  7 11 15  6]
#  [ 5  3  4 12  6  7  9]]
# 0.2937966110459697

# %%
# SVM test:

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(x_train)
# X_test_scaled = scaler.transform(x_val)


# rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
# # poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# poly_pred = poly.predict(X_test)
# rbf_pred = rbf.predict(X_test)

# poly_accuracy = accuracy_score(y_test, poly_pred)
# poly_f1 = f1_score(y_test, poly_pred, average='weighted')
# print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
# print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))

# %%
# Xtrain, Xval, Ytrain, Yval = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

# %%
lr=0.001
batch_size=8
epochs=50
history=model.fit(x_train, y_train,
                  epochs=epochs,
                  validation_data=(x_val, y_val),
                  batch_size=batch_size)

# %%
lr=0.001
batch_size=8
epochs=50
history=model.fit(x_train, y_train,
                  epochs=epochs,
                  validation_data=(x_val, y_val),
                  batch_size=batch_size)
# Out:
# Epoch 1/50
50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.6512 - categorical_accuracy: 0.7964 - accuracy: 0.7964 - val_loss: 2.5299 - val_categorical_accuracy: 0.2946 - val_accuracy: 0.2946
# Epoch 46/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.6117 - categorical_accuracy: 0.8122 - accuracy: 0.8122 - val_loss: 2.5463 - val_categorical_accuracy: 0.2946 - val_accuracy: 0.2946
# Epoch 47/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.6579 - categorical_accuracy: 0.8031 - accuracy: 0.8031 - val_loss: 2.5539 - val_categorical_accuracy: 0.2973 - val_accuracy: 0.2973
# Epoch 48/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.7102 - categorical_accuracy: 0.7680 - accuracy: 0.7680 - val_loss: 2.5576 - val_categorical_accuracy: 0.2973 - val_accuracy: 0.2973
# Epoch 49/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.6874 - categorical_accuracy: 0.7847 - accuracy: 0.7847 - val_loss: 2.5681 - val_categorical_accuracy: 0.2946 - val_accuracy: 0.2946
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.6823 - categorical_accuracy: 0.7770 - accuracy: 0.7770 - val_loss: 2.5699 - val_categorical_accuracy: 0.3000 - val_accuracy: 0.3000

# %%
def plot_model(history,title):
  plt.figure()
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  # plt.plot(history.history['val_categorical_accuracy'])
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.title("model train and val accuracy from "+title)
  # plt.savefig("Combinedmodel1.png")
  # plt.show()
  
  plt.figure()
  plt.plot(history.history['val_accuracy'])
  plt.title("Validation accuracy " + title)

  plt.figure()
  plt.plot(history.history['val_categorical_accuracy'])
  plt.title("Validation categorical accuracy"+title)

plot_model(history,"test 1 combined model")

# %%
#Test amb conjunt de test extret del de train 
lr=0.001
batch_size=8
epochs=50

history=model.fit(Xtrain, Ytrain,
                   epochs=epochs,
                   validation_data=(Xval, Yval),
                   batch_size=batch_size)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 1s 11ms/step - loss: 1.8869 - categorical_accuracy: 0.2916 - accuracy: 0.2916 - val_loss: 1.8005 - val_categorical_accuracy: 0.5158 - val_accuracy: 0.5158
# Epoch 2/50
# 36/36 [==============================] - 0s 3ms/step - loss: 1.8022 - categorical_accuracy: 0.4449 - accuracy: 0.4449 - val_loss: 1.7160 - val_categorical_accuracy: 0.5789 - val_accuracy: 0.5789
# Epoch 3/50
# 36/36 [==============================] - 0s 4ms/step - loss: 1.7290 - categorical_accuracy: 0.4706 - accuracy: 0.4706 - val_loss: 1.6332 - val_categorical_accuracy: 0.6000 - val_accuracy: 0.6000
# Epoch 4/50
# 36/36 [==============================] - 0s 3ms/step - loss: 1.6749 - categorical_accuracy: 0.5006 - accuracy: 0.5006 - val_loss: 1.5484 - val_categorical_accuracy: 0.6316 - val_accuracy: 0.6316
# Epoch 5/50
# 36/36 [==============================] - 0s 3ms/step - loss: 1.5804 - categorical_accuracy: 0.5410 - accuracy: 0.5410 - val_loss: 1.4700 - val_categorical_accuracy: 0.6421 - val_accuracy: 0.6421
# Epoch 6/50
# 36/36 [==============================] - 0s 10ms/step - loss: 1.4776 - categorical_accuracy: 0.5940 - accuracy: 0.5940 - val_loss: 1.3966 - val_categorical_accuracy: 0.6526 - val_accuracy: 0.6526
# Epoch 7/50
# 36/36 [==============================] - 0s 4ms/step - loss: 1.4021 - categorical_accuracy: 0.6001 - accuracy: 0.6001 - val_loss: 1.3316 - val_categorical_accuracy: 0.6632 - val_accuracy: 0.6632
# Epoch 8/50
# 36/36 [==============================] - 0s 3ms/step - loss: 1
- val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 27/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7529 - categorical_accuracy: 0.8013 - accuracy: 0.8013 - val_loss: 0.7096 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 28/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7723 - categorical_accuracy: 0.8219 - accuracy: 0.8219 - val_loss: 0.6957 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 29/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.8022 - categorical_accuracy: 0.7626 - accuracy: 0.7626 - val_loss: 0.6851 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 30/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7318 - categorical_accuracy: 0.8304 - accuracy: 0.8304 - val_loss: 0.6756 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 31/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.8043 - categorical_accuracy: 0.7697 - accuracy: 0.7697 - val_loss: 0.6624 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 32/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7725 - categorical_accuracy: 0.7972 - accuracy: 0.7972 - val_loss: 0.6466 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 33/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7528 - categorical_accuracy: 0.7858 - accuracy: 0.7858 - val_loss: 0.6403 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 34/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6693 - categorical_accuracy: 0.8265 - accuracy: 0.8265 - val_loss: 0.6345 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 35/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7653 - categorical_accuracy: 0.7421 - accuracy: 0.7421 - val_loss: 0.6239 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 36/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6238 - categorical_accuracy: 0.8269 - accuracy: 0.8269 - val_loss: 0.6166 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 37/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6155 - categorical_accuracy: 0.8082 - accuracy: 0.8082 - val_loss: 0.6077 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 38/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6362 - categorical_accuracy: 0.8140 - accuracy: 0.8140 - val_loss: 0.6028 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 39/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7432 - categorical_accuracy: 0.7621 - accuracy: 0.7621 - val_loss: 0.5906 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 40/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6923 - categorical_accuracy: 0.7810 - accuracy: 0.7810 - val_loss: 0.5865 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 41/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6477 - categorical_accuracy: 0.8068 - accuracy: 0.8068 - val_loss: 0.5833 - val_categorical_accuracy: 0.8421 - val_accuracy: 0.8421
# Epoch 42/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6023 - categorical_accuracy: 0.8346 - accuracy: 0.8346 - val_loss: 0.5762 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 43/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.5689 - categorical_accuracy: 0.8543 - accuracy: 0.8543 - val_loss: 0.5692 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 44/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.4823 - categorical_accuracy: 0.8600 - accuracy: 0.8600 - val_loss: 0.5646 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 45/50
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5810 - categorical_accuracy: 0.8392 - accuracy: 0.8392 - val_loss: 0.5558 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 46/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6582 - categorical_accuracy: 0.7980 - accuracy: 0.7980 - val_loss: 0.5540 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 47/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5821 - categorical_accuracy: 0.8308 - accuracy: 0.8308 - val_loss: 0.5471 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 48/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5514 - categorical_accuracy: 0.8308 - accuracy: 0.8308 - val_loss: 0.5448 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 49/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5724 - categorical_accuracy: 0.8453 - accuracy: 0.8453 - val_loss: 0.5388 - val_categorical_accuracy: 0.8316 - val_accuracy: 0.8316
# Epoch 50/50
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6037 - categorical_accuracy: 0.8201 - accuracy: 0.8201 - val_loss: 0.5343 - val_categorical_accuracy: 0.8526 - val_accuracy: 0.8526

# %%
predictions=model.predict(x_val)
one_hot_preds= [get_one_hot_pred(pred) for pred in predictions]
emo_preds=[get_emo_value(pred) for pred in predictions]
emo_val=[ get_emo_value(pred) for pred in y_val]

# one_hot_preds

# %%
print("accuracy: ",accuracy_score(y_val, one_hot_preds))
print(confusion_matrix(emo_val, emo_preds))
print("f1: ",f1_score(real_labels, predictions),average='weighted')
# Out:
# accuracy:  0.3
# [[25  9  1 10  3  7  4]
#  [ 7 10  1 10  3  8  0]
#  [ 8  6  9  6  5  3  7]
#  [ 7 11  6 22  5 10  2]
#  [ 8  6  2 12 22  7  3]
#  [ 6  7  8  7 10 16  5]
#  [ 5  4  4 13  5  8  7]]

# %%
predictions.shape
# Out:
# (188, 7)

# %%
model.save("CombinedModel1.h5")

# %%
# Out:
# [<keras.layers.core.Dense at 0x7f66980fccd0>,
#  <keras.layers.core.Dropout at 0x7f66981e7ad0>,
#  <keras.layers.core.Dense at 0x7f6698122f90>]

# %%
print("accuracy: ",accuracy_score(y_val, one_hot_preds))
print(confusion_matrix(emo_val, emo_preds))
print("f1: ",f1_score(emo_val, emo_preds,average='weighted'))
# Out:
# accuracy:  0.3
# [[25  9  1 10  3  7  4]
#  [ 7 10  1 10  3  8  0]
#  [ 8  6  9  6  5  3  7]
#  [ 7 11  6 22  5 10  2]
#  [ 8  6  2 12 22  7  3]
#  [ 6  7  8  7 10 16  5]
#  [ 5  4  4 13  5  8  7]]
# f1:  0.2975362454467308

# %%
params={}
params["num_prueba"]="P1 combinacion audio video"
params["model_name"]="CombinedModel1.h5"
params["description"]="Combinacion del modelo de video del sfew con las imagenes del sfew ordenados por video segun etiquetas del afew"
params["model description"]="Modelo vgg entrenado imagenes y vgg imagenes specs audio combinado con capa densa 28 neuronas relu y dropout capa final 7 neuronas softmax "
params["DROPOUT"]=0.25
params["learning rate"]=lr
params["N_OUTPUT_LABELS"]=N_OUTPUT_LABELS
params["batch_size"]=batch_size
params["epochs"]=epochs


with open("/content/results_comb_model.csv", 'a') as f: 
  dictwriter_object = DictWriter(f, fieldnames=params.keys()) 
  dictwriter_object .writeheader()
  dictwriter_object.writerow(params) 
  f.close()

# %%
# predictions_dict_paths=["/content/vgg_audio_model_preds_train.pkl","/content/vgg_audio_model_preds_test.pkl",
#                "/content/sfew_predictions_tr.pkl","/content/sfew_predictions_te.pkl"]


# with open(predictions_dict_paths[0], 'rb') as f:
#     audio_train_preds = pickle.load(f)

# with open(predictions_dict_paths[1], 'rb') as f:
#   audio_test_preds = pickle.load(f)

# # with open(predictions_dict_paths[2], 'rb') as f:
# #     sfew_video_train_preds = pickle.load(f) 

# # with open(predictions_dict_paths[3], 'rb') as f:
# #     sfew_video_test_preds = pickle.load(f)

# # with open("/content/train_video_labels.pkl", 'rb') as f:
# #     train_video_labels = pickle.load(f)

# # with open("/content/val_video_labels.pkl", 'rb') as f:
# #     val_video_labels = pickle.load(f)


# #new m2:


# m2_predictions_dict_paths=["/content/afew_images_SFEWpredictions__m2_te.pkl",
#                            "/content/afew_images_SFEWpredictions_m2_tr.pkl"]  # aquests noms haurien de dir sfew


# with open(m2_predictions_dict_paths[1], 'rb') as f:
#     sfew_video_train_preds_m2 = pickle.load(f) 

# with open(m2_predictions_dict_paths[0], 'rb') as f:
#     sfew_video_test_preds_m2 = pickle.load(f)
